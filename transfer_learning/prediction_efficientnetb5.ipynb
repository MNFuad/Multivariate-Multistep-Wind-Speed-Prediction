# %%
from google.colab import drive
drive.mount('/content/drive/')
# %cd /content/drive/My\ Drive/Colab\ Notebooks\

# from tensorflow.keras.applications.vgg19 import VGG19
# from tensorflow.keras.applications.mobilenet_v2  import MobileNetV2
# from tensorflow.keras.applications.nasnet import NASNetLarge 
# from tensorflow.keras.applications.xception import Xception
# from tensorflow.keras.applications.resnet50 import ResNet50
# from tensorflow.keras.applications.resnet import ResNet101
# from tensorflow.keras.applications.resnet import ResNet152
# from tensorflow.keras.applications.resnet_v2 import ResNet50V2
# from tensorflow.keras.applications.resnet_v2 import ResNet101V2
# from tensorflow.keras.applications.resnet_v2 import ResNet152V2
# from tensorflow.keras.applications.inception_v3 import InceptionV3
# from tensorflow.keras.applications.inception_resnet_v2 import InceptionResNetV2	
# from tensorflow.keras.applications.mobilenet import MobileNet
# from tensorflow.keras.applications.densenet import DenseNet121
# from tensorflow.keras.applications.densenet import DenseNet169
# from tensorflow.keras.applications.densenet import DenseNet201
# from tensorflow.keras.applications.nasnet import NASNetMobile
# from tensorflow.keras.applications.nasnet import NASNetLarge
# from tensorflow.python.keras.applications.efficientnet import EfficientNetB0
# from tensorflow.python.keras.applications.efficientnet import EfficientNetB1
# from tensorflow.python.keras.applications.efficientnet import EfficientNetB2
# from tensorflow.python.keras.applications.efficientnet import EfficientNetB3
# from tensorflow.python.keras.applications.efficientnet import EfficientNetB4
from tensorflow.python.keras.applications.efficientnet import EfficientNetB5
# from tensorflow.python.keras.applications.efficientnet import EfficientNetB6
# from tensorflow.python.keras.applications.efficientnet import EfficientNetB7
from tensorflow.keras.layers import Input, Dropout
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Dense, GlobalAveragePooling2D
import numpy as np
from keras.utils import to_categorical
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint
from tensorflow.keras.callbacks import ReduceLROnPlateau
from tensorflow.keras.optimizers import Adam, RMSprop 
# !pip install keras-adamw
# from keras_adamw import AdamW
import os
from sklearn.utils import shuffle
from keras.utils import np_utils
import scipy.io as sio

# filename = 'NASNetLarge_tuning' 
# filename = 'Xception_tuning'
# filename = 'mobilenetV2_tuning'
# filename = 'ResNet50_tuning'
# filename = 'ResNet101_tuning'
# filename = 'ResNet152_tuning'
# filename = 'ResNet50V2_tuning' 
# filename = 'ResNet101V2_tuning' 
# filename = 'ResNet152V2_tuning' 
# filename = 'InceptionV3_tuning' 
# filename = 'InceptionResNetV2_tuning' 
# filename = 'MobileNet_tuning' 
# filename = 'DenseNet121_tuning' 
# filename = 'DenseNet169_tuning' 
# filename = 'DenseNet201_tuning' 
# filename = 'NASNetMobile_tuning' 
# filename = 'EfficientNetB0_tuning' 
# filename = 'EfficientNetB1_tuning'
# filename = 'EfficientNetB2_tuning'
# filename = 'EfficientNetB3_tuning'
# filename = 'EfficientNetB4_tuning'
filename = 'EfficientNetB5_tuning'
# filename = 'EfficientNetB6_tuning'
# filename = 'EfficientNetB7_tuning'
#=============================================================================
print('Loading data...')
ExType = 'H1'
DataPath = './wind_data/Norm_Train_Val_data_Lag10_'+ExType+'.mat'   
train_data = sio.loadmat(DataPath)['XTrain']#[...,np.newaxis]
train_labels = sio.loadmat(DataPath)['YTrain']
train_labels = np.squeeze(train_labels)
valid_data = sio.loadmat(DataPath)['XVal']#[...,np.newaxis]
valid_labels = sio.loadmat(DataPath)['YVal']
valid_labels = np.squeeze(valid_labels)

print('Wind Train data dim.   (samples x lag x parameters)',train_data.shape)
print('Wind Train labels dim. (samples x lag x parameters)',train_labels.shape)
print('Wind Valid dim.        (samples x lag x parameters)',valid_data.shape)
print('Wind Valid labels dim. (samples x lag x parameters)',valid_labels.shape)

# data resizing
resizeTo = 32
from tensorflow.keras.preprocessing.image import array_to_img
train_images = np.zeros((train_data.shape[0],resizeTo,resizeTo))
for i, im in enumerate(train_data):
  a = array_to_img(train_data[i,:, :, np.newaxis])
  train_images[i,...] = np.array(a.resize((resizeTo,resizeTo)))
valid_images = np.zeros((valid_data.shape[0],resizeTo,resizeTo))
for i, im in enumerate(valid_data):
  a = array_to_img(valid_data[i,:, :, np.newaxis])
  valid_images[i,...] = np.array(a.resize((resizeTo,resizeTo)))


# duplicate the data three times to look like rgb image
train_data = np.repeat(train_images[:, :, :, np.newaxis], 3, axis=3)
valid_data = np.repeat(valid_images[:, :, :, np.newaxis], 3, axis=3)
print('Wind Train images dim.   (samples x lag x parameters x channels)',train_data.shape)
#=============================================================================
    

base_model = EfficientNetB5(weights='imagenet', include_top=False,
                      input_tensor=Input(shape=(train_data.shape[1],train_data.shape[2],3)))# new input shape 


noLayers = len(base_model.layers)
# add a global spatial average pooling layer
x = base_model.output
x = GlobalAveragePooling2D()(x)
# let's add a fully-connected layer
x = Dense(1024, activation='relu')(x)
x = Dropout(rate=0.2)(x)
x = Dense(512, activation='relu')(x)
x = Dropout(rate=0.2)(x)
# x = Dense(256, activation='relu')(x)
# and a logistic layer -- let's say we have 200 classes
predictions = Dense(1, activation='linear')(x)

# this is the model we will train
model = Model(inputs=base_model.input, outputs=predictions)

# first: train only the top layers (which were randomly initialized)
# i.e. freeze all convolutional InceptionV3 layers
# for layer in base_model.layers[:noLayers]:
#     layer.trainable = False

#second: fine tune all layers with small learning rate
# Unfreeze the base model
base_model.trainable = False
# print(model.summary())
# compile the model (should be done *after* setting layers to non-trainable)
optimizer = Adam(lr=1e-03, beta_1=0.9, beta_2=0.999, epsilon=1e-08, decay=1e-06, amsgrad=False)
# optimizer = RMSprop(learning_rate=0.001, rho=0.9, momentum=0.9, epsilon=1e-07)
# optimizer = AdamW(lr=1e-4, model=model)
model.compile(optimizer=optimizer, loss='mse',metrics=['mae','mse'])

saveTo = './models/'+ExType
if not os.path.exists(saveTo):
    os.makedirs(saveTo)
    
callbacks=[ReduceLROnPlateau(monitor='val_loss', factor=0.2, patience=20, 
            verbose=1, mode='auto', min_delta=0.0005, min_lr=1e-07),#0.0001
            EarlyStopping(monitor='val_loss', patience=20, verbose=1, mode='auto'),
            ModelCheckpoint(saveTo + '/best_'+filename+'.hdf5', monitor='val_loss', verbose=1, 
                            save_best_only=True, mode='auto')]

model.fit(train_data,train_labels,
          batch_size=128,
          epochs=100,
          shuffle=True,
          validation_data=(valid_data,valid_labels),
          verbose=1,
          callbacks=callbacks)
# Testing
# from sklearn.metrics import confusion_matrix
# import sklearn.metrics as skm
import matplotlib.pyplot as plt
from sklearn.metrics import mean_squared_error, mean_absolute_error
from math import sqrt

predictions = model.predict(valid_data,verbose=1)
# MAPE = np.mean(100*2.0 * np.abs(valid_labels - predictions) / (np.abs(valid_labels) + np.abs(predictions))).item()
MAPE = np.mean(np.abs((valid_labels - predictions) / valid_labels)) * 100
print("MAE {:.4}, MSE {:.4f}, RMSE {:.4f}, MAPE {:.4f}".format(
    mean_absolute_error(valid_labels, predictions),
    mean_squared_error(valid_labels, predictions),
    sqrt(mean_squared_error(valid_labels, predictions)),
    MAPE))
plt.scatter(valid_labels,predictions)
plt.figure(figsize=(30,6)); 
plt.plot(valid_labels, label='true')
plt.plot(predictions, label='pred')
plt.legend()
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive/
# /content/drive/My Drive/Colab Notebooks
# Using TensorFlow backend.
# Loading data...
# Wind Train data dim.   (samples x lag x parameters) (42039, 10, 10)
# Wind Train labels dim. (samples x lag x parameters) (42039,)
# Wind Valid dim.        (samples x lag x parameters) (10502, 10, 10)
# Wind Valid labels dim. (samples x lag x parameters) (10502,)
# Wind Train images dim.   (samples x lag x parameters x channels) (42039, 32, 32, 3)
# Downloading data from https://storage.googleapis.com/keras-applications/efficientnetb5_notop.h5
# 115269632/115263384 [==============================] - 3s 0us/step
# Epoch 1/100
# 329/329 [==============================] - ETA: 0s - loss: 1.2880 - mae: 0.7501 - mse: 1.2880
# Epoch 00001: val_loss improved from inf to 0.98251, saving model to ./models/H1/best_EfficientNetB5_tuning.hdf5
# 329/329 [==============================] - 25s 76ms/step - loss: 1.2880 - mae: 0.7501 - mse: 1.2880 - val_loss: 0.9825 - val_mae: 0.7458 - val_mse: 0.9825 - lr: 0.0010
# Epoch 2/100
# 328/329 [============================>.] - ETA: 0s - loss: 0.9948 - mae: 0.6914 - mse: 0.9948
# Epoch 00002: val_loss did not improve from 0.98251
# 329/329 [==============================] - 20s 61ms/step - loss: 0.9947 - mae: 0.6914 - mse: 0.9947 - val_loss: 0.9862 - val_mae: 0.7583 - val_mse: 0.9862 - lr: 0.0010
# Epoch 3/100
# 328/329 [============================>.] - ETA: 0s - loss: 0.9754 - mae: 0.6836 - mse: 0.9754
# Epoch 00003: val_loss improved from 0.98251 to 0.92182, saving model to ./models/H1/best_EfficientNetB5_tuning.hdf5
# 329/329 [==============================] - 22s 68ms/step - loss: 0.9756 - mae: 0.6836 - mse: 0.9756 - val_loss: 0.9218 - val_mae: 0.7309 - val_mse: 0.9218 - lr: 0.0010
# Epoch 4/100
# 329/329 [==============================] - ETA: 0s - loss: 0.9680 - mae: 0.6832 - mse: 0.9680
# Epoch 00004: val_loss improved from 0.92182 to 0.90566, saving model to ./models/H1/best_EfficientNetB5_tuning.hdf5
# 329/329 [==============================] - 22s 68ms/step - loss: 0.9680 - mae: 0.6832 - mse: 0.9680 - val_loss: 0.9057 - val_mae: 0.7120 - val_mse: 0.9057 - lr: 0.0010
# Epoch 5/100
# 329/329 [==============================] - ETA: 0s - loss: 0.9556 - mae: 0.6788 - mse: 0.9556
# Epoch 00005: val_loss did not improve from 0.90566
# 329/329 [==============================] - 20s 60ms/step - loss: 0.9556 - mae: 0.6788 - mse: 0.9556 - val_loss: 0.9185 - val_mae: 0.7524 - val_mse: 0.9185 - lr: 0.0010
# Epoch 6/100
# 329/329 [==============================] - ETA: 0s - loss: 0.9497 - mae: 0.6790 - mse: 0.9497
# Epoch 00006: val_loss did not improve from 0.90566
# 329/329 [==============================] - 20s 60ms/step - loss: 0.9497 - mae: 0.6790 - mse: 0.9497 - val_loss: 0.9089 - val_mae: 0.7199 - val_mse: 0.9089 - lr: 0.0010
# Epoch 7/100
# 328/329 [============================>.] - ETA: 0s - loss: 0.9456 - mae: 0.6773 - mse: 0.9456
# Epoch 00007: val_loss did not improve from 0.90566
# 329/329 [==============================] - 20s 60ms/step - loss: 0.9453 - mae: 0.6772 - mse: 0.9453 - val_loss: 0.9175 - val_mae: 0.7563 - val_mse: 0.9175 - lr: 0.0010
# Epoch 8/100
# 328/329 [============================>.] - ETA: 0s - loss: 0.9404 - mae: 0.6764 - mse: 0.9404
# Epoch 00008: val_loss improved from 0.90566 to 0.87897, saving model to ./models/H1/best_EfficientNetB5_tuning.hdf5
# 329/329 [==============================] - 22s 67ms/step - loss: 0.9413 - mae: 0.6765 - mse: 0.9413 - val_loss: 0.8790 - val_mae: 0.7308 - val_mse: 0.8790 - lr: 0.0010
# Epoch 9/100
# 329/329 [==============================] - ETA: 0s - loss: 0.9304 - mae: 0.6741 - mse: 0.9304
# Epoch 00009: val_loss did not improve from 0.87897
# 329/329 [==============================] - 20s 60ms/step - loss: 0.9304 - mae: 0.6741 - mse: 0.9304 - val_loss: 0.8886 - val_mae: 0.7456 - val_mse: 0.8886 - lr: 0.0010
# Epoch 10/100
# 328/329 [============================>.] - ETA: 0s - loss: 0.9206 - mae: 0.6718 - mse: 0.9206
# Epoch 00010: val_loss improved from 0.87897 to 0.86823, saving model to ./models/H1/best_EfficientNetB5_tuning.hdf5
# 329/329 [==============================] - 22s 67ms/step - loss: 0.9198 - mae: 0.6715 - mse: 0.9198 - val_loss: 0.8682 - val_mae: 0.6938 - val_mse: 0.8682 - lr: 0.0010
# Epoch 11/100
# 329/329 [==============================] - ETA: 0s - loss: 0.9081 - mae: 0.6691 - mse: 0.9081
# Epoch 00011: val_loss did not improve from 0.86823
# 329/329 [==============================] - 20s 60ms/step - loss: 0.9081 - mae: 0.6691 - mse: 0.9081 - val_loss: 0.9506 - val_mae: 0.7833 - val_mse: 0.9506 - lr: 0.0010
# Epoch 12/100
# 328/329 [============================>.] - ETA: 0s - loss: 0.9116 - mae: 0.6674 - mse: 0.9116
# Epoch 00012: val_loss improved from 0.86823 to 0.86415, saving model to ./models/H1/best_EfficientNetB5_tuning.hdf5
# 329/329 [==============================] - 22s 67ms/step - loss: 0.9110 - mae: 0.6671 - mse: 0.9110 - val_loss: 0.8642 - val_mae: 0.6809 - val_mse: 0.8642 - lr: 0.0010
# Epoch 13/100
# 328/329 [============================>.] - ETA: 0s - loss: 0.9053 - mae: 0.6656 - mse: 0.9053
# Epoch 00013: val_loss did not improve from 0.86415
# 329/329 [==============================] - 20s 60ms/step - loss: 0.9050 - mae: 0.6656 - mse: 0.9050 - val_loss: 0.8712 - val_mae: 0.7258 - val_mse: 0.8712 - lr: 0.0010
# Epoch 14/100
# 329/329 [==============================] - ETA: 0s - loss: 0.8944 - mae: 0.6633 - mse: 0.8944
# Epoch 00014: val_loss did not improve from 0.86415
# 329/329 [==============================] - 20s 59ms/step - loss: 0.8944 - mae: 0.6633 - mse: 0.8944 - val_loss: 0.8674 - val_mae: 0.7131 - val_mse: 0.8674 - lr: 0.0010
# Epoch 15/100
# 328/329 [============================>.] - ETA: 0s - loss: 0.
- lr: 0.0010
# Epoch 41/100
# 329/329 [==============================] - ETA: 0s - loss: 0.8281 - mae: 0.6404 - mse: 0.8281
# Epoch 00041: val_loss did not improve from 0.79853
# 329/329 [==============================] - 20s 59ms/step - loss: 0.8281 - mae: 0.6404 - mse: 0.8281 - val_loss: 0.8363 - val_mae: 0.6905 - val_mse: 0.8363 - lr: 0.0010
# Epoch 42/100
# 328/329 [============================>.] - ETA: 0s - loss: 0.8279 - mae: 0.6386 - mse: 0.8279
# Epoch 00042: val_loss did not improve from 0.79853
# 329/329 [==============================] - 19s 59ms/step - loss: 0.8278 - mae: 0.6387 - mse: 0.8278 - val_loss: 1.0310 - val_mae: 0.7958 - val_mse: 1.0310 - lr: 0.0010
# Epoch 43/100
# 329/329 [==============================] - ETA: 0s - loss: 0.8144 - mae: 0.6361 - mse: 0.8144
# Epoch 00043: val_loss did not improve from 0.79853
# 329/329 [==============================] - 20s 59ms/step - loss: 0.8144 - mae: 0.6361 - mse: 0.8144 - val_loss: 0.8011 - val_mae: 0.6776 - val_mse: 0.8011 - lr: 0.0010
# Epoch 44/100
# 329/329 [==============================] - ETA: 0s - loss: 0.8362 - mae: 0.6397 - mse: 0.8362
# Epoch 00044: val_loss did not improve from 0.79853
# 329/329 [==============================] - 19s 59ms/step - loss: 0.8362 - mae: 0.6397 - mse: 0.8362 - val_loss: 0.9240 - val_mae: 0.7402 - val_mse: 0.9240 - lr: 0.0010
# Epoch 45/100
# 329/329 [==============================] - ETA: 0s - loss: 0.8143 - mae: 0.6344 - mse: 0.8143
# Epoch 00045: val_loss did not improve from 0.79853
# 329/329 [==============================] - 19s 59ms/step - loss: 0.8143 - mae: 0.6344 - mse: 0.8143 - val_loss: 1.4080 - val_mae: 0.9121 - val_mse: 1.4080 - lr: 0.0010
# Epoch 46/100
# 328/329 [============================>.] - ETA: 0s - loss: 0.8222 - mae: 0.6369 - mse: 0.8222
# Epoch 00046: val_loss did not improve from 0.79853
# 329/329 [==============================] - 20s 59ms/step - loss: 0.8235 - mae: 0.6372 - mse: 0.8235 - val_loss: 1.2280 - val_mae: 0.8515 - val_mse: 1.2280 - lr: 0.0010
# Epoch 47/100
# 328/329 [============================>.] - ETA: 0s - loss: 0.8266 - mae: 0.6373 - mse: 0.8266
# Epoch 00047: val_loss did not improve from 0.79853
# 329/329 [==============================] - 19s 59ms/step - loss: 0.8263 - mae: 0.6372 - mse: 0.8263 - val_loss: 0.8076 - val_mae: 0.6795 - val_mse: 0.8076 - lr: 0.0010
# Epoch 48/100
# 329/329 [==============================] - ETA: 0s - loss: 0.8233 - mae: 0.6380 - mse: 0.8233
# Epoch 00048: val_loss did not improve from 0.79853
# 329/329 [==============================] - 19s 59ms/step - loss: 0.8233 - mae: 0.6380 - mse: 0.8233 - val_loss: 0.8286 - val_mae: 0.7062 - val_mse: 0.8286 - lr: 0.0010
# Epoch 49/100
# 328/329 [============================>.] - ETA: 0s - loss: 0.8141 - mae: 0.6359 - mse: 0.8141
# Epoch 00049: val_loss did not improve from 0.79853
# 329/329 [==============================] - 19s 59ms/step - loss: 0.8139 - mae: 0.6358 - mse: 0.8139 - val_loss: 0.8935 - val_mae: 0.7357 - val_mse: 0.8935 - lr: 0.0010
# Epoch 50/100
# 329/329 [==============================] - ETA: 0s - loss: 0.8293 - mae: 0.6394 - mse: 0.8293
# Epoch 00050: val_loss did not improve from 0.79853
# 329/329 [==============================] - 19s 59ms/step - loss: 0.8293 - mae: 0.6394 - mse: 0.8293 - val_loss: 0.9579 - val_mae: 0.7539 - val_mse: 0.9579 - lr: 0.0010
# Epoch 51/100
# 328/329 [============================>.] - ETA: 0s - loss: 0.8156 - mae: 0.6334 - mse: 0.8156
# Epoch 00051: val_loss did not improve from 0.79853
# 329/329 [==============================] - 19s 59ms/step - loss: 0.8151 - mae: 0.6333 - mse: 0.8151 - val_loss: 0.8384 - val_mae: 0.7005 - val_mse: 0.8384 - lr: 0.0010
# Epoch 52/100
# 328/329 [============================>.] - ETA: 0s - loss: 0.8144 - mae: 0.6351 - mse: 0.8144
# Epoch 00052: val_loss did not improve from 0.79853
# 329/329 [==============================] - 19s 59ms/step - loss: 0.8142 - mae: 0.6350 - mse: 0.8142 - val_loss: 1.0948 - val_mae: 0.8126 - val_mse: 1.0948 - lr: 0.0010
# Epoch 53/100
# 328/329 [============================>.] - ETA: 0s - loss: 0.8096 - mae: 0.6321 - mse: 0.8096
# Epoch 00053: val_loss did not improve from 0.79853
# 329/329 [==============================] - 19s 59ms/step - loss: 0.8096 - mae: 0.6321 - mse: 0.8096 - val_loss: 1.1644 - val_mae: 0.8251 - val_mse: 1.1644 - lr: 0.0010
# Epoch 54/100
# 329/329 [==============================] - ETA: 0s - loss: 0.8215 - mae: 0.6379 - mse: 0.8215
# Epoch 00054: val_loss improved from 0.79853 to 0.77751, saving model to ./models/H1/best_EfficientNetB5_tuning.hdf5
# 329/329 [==============================] - 22s 67ms/step - loss: 0.8215 - mae: 0.6379 - mse: 0.8215 - val_loss: 0.7775 - val_mae: 0.6572 - val_mse: 0.7775 - lr: 0.0010
# Epoch 55/100
# 328/329 [============================>.] - ETA: 0s - loss: 0.8188 - mae: 0.6355 - mse: 0.8188
# Epoch 00055: val_loss did not improve from 0.77751
# 329/329 [==============================] - 19s 59ms/step - loss: 0.8186 - mae: 0.6355 - mse: 0.8186 - val_loss: 0.8292 - val_mae: 0.7058 - val_mse: 0.8292 - lr: 0.0010
# Epoch 56/100
# 329/329 [==============================] - ETA: 0s - loss: 0.8086 - mae: 0.6329 - mse: 0.8086
# Epoch 00056: val_loss did not improve from 0.77751
# 329/329 [==============================] - 19s 59ms/step - loss: 0.8086 - mae: 0.6329 - mse: 0.8086 - val_loss: 0.7810 - val_mae: 0.6608 - val_mse: 0.7810 - lr: 0.0010
# Epoch 57/100
# 328/329 [============================>.] - ETA: 0s - loss: 0.7950 - mae: 0.6296 - mse: 0.7950
# Epoch 00057: val_loss did not improve from 0.77751
# 329/329 [==============================] - 19s 59ms/step - loss: 0.7950 - mae: 0.6296 - mse: 0.7950 - val_loss: 0.8006 - val_mae: 0.6764 - val_mse: 0.8006 - lr: 0.0010
# Epoch 58/100
# 329/329 [==============================] - ETA: 0s - loss: 0.8139 - mae: 0.6336 - mse: 0.8139
# Epoch 00058: val_loss did not improve from 0.77751
# 329/329 [==============================] - 19s 59ms/step - loss: 0.8139 - mae: 0.6336 - mse: 0.8139 - val_loss: 1.3599 - val_mae: 0.9060 - val_mse: 1.3599 - lr: 0.0010
# Epoch 59/100
# 329/329 [==============================] - ETA: 0s - loss: 0.8092 - mae: 0.6307 - mse: 0.8092
# Epoch 00059: val_loss did not improve from 0.77751
# 329/329 [==============================] - 19s 59ms/step - loss: 0.8092 - mae: 0.6307 - mse: 0.8092 - val_loss: 0.8266 - val_mae: 0.6809 - val_mse: 0.8266 - lr: 0.0010
# Epoch 60/100
# 328/329 [============================>.] - ETA: 0s - loss: 0.8061 - mae: 0.6333 - mse: 0.8061
# Epoch 00060: val_loss did not improve from 0.77751
# 329/329 [==============================] - 19s 59ms/step - loss: 0.8060 - mae: 0.6333 - mse: 0.8060 - val_loss: 0.9222 - val_mae: 0.7329 - val_mse: 0.9222 - lr: 0.0010
# Epoch 61/100
# 329/329 [==============================] - ETA: 0s - loss: 0.8060 - mae: 0.6303 - mse: 0.8060
# Epoch 00061: val_loss did not improve from 0.77751
# 329/329 [==============================] - 19s 59ms/step - loss: 0.8060 - mae: 0.6303 - mse: 0.8060 - val_loss: 0.8012 - val_mae: 0.6899 - val_mse: 0.8012 - lr: 0.0010
# Epoch 62/100
# 328/329 [============================>.] - ETA: 0s - loss: 0.8078 - mae: 0.6326 - mse: 0.8078
# Epoch 00062: val_loss did not improve from 0.77751
# 329/329 [==============================] - 20s 59ms/step - loss: 0.8076 - mae: 0.6325 - mse: 0.8076 - val_loss: 0.7918 - val_mae: 0.6576 - val_mse: 0.7918 - lr: 0.0010
# Epoch 63/100
# 329/329 [==============================] - ETA: 0s - loss: 0.8270 - mae: 0.6365 - mse: 0.8270
# Epoch 00063: val_loss did not improve from 0.77751
# 329/329 [==============================] - 19s 59ms/step - loss: 0.8270 - mae: 0.6365 - mse: 0.8270 - val_loss: 0.9049 - val_mae: 0.7237 - val_mse: 0.9049 - lr: 0.0010
# Epoch 64/100
# 328/329 [============================>.] - ETA: 0s - loss: 0.7922 - mae: 0.6279 - mse: 0.7922
# Epoch 00064: val_loss did not improve from 0.77751
# 329/329 [==============================] - 19s 59ms/step - loss: 0.7919 - mae: 0.6279 - mse: 0.7919 - val_loss: 0.8354 - val_mae: 0.7037 - val_mse: 0.8354 - lr: 0.0010
# Epoch 65/100
# 329/329 [==============================] - ETA: 0s - loss: 0.7888 - mae: 0.6273 - mse: 0.7888
# Epoch 00065: val_loss did not improve from 0.77751
# 329/329 [==============================] - 19s 59ms/step - loss: 0.7888 - mae: 0.6273 - mse: 0.7888 - val_loss: 0.8755 - val_mae: 0.7056 - val_mse: 0.8755 - lr: 0.0010
# Epoch 66/100
# 328/329 [============================>.] - ETA: 0s - loss: 0.7808 - mae: 0.6215 - mse: 0.7808
# Epoch 00066: val_loss did not improve from 0.77751
# 329/329 [==============================] - 19s 59ms/step - loss: 0.7806 - mae: 0.6214 - mse: 0.7806 - val_loss: 0.9519 - val_mae: 0.7397 - val_mse: 0.9519 - lr: 0.0010
# Epoch 67/100
# 328/329 [============================>.] - ETA: 0s - loss: 0.7983 - mae: 0.6289 - mse: 0.7983
# Epoch 00067: val_loss improved from 0.77751 to 0.76764, saving model to ./models/H1/best_EfficientNetB5_tuning.hdf5
# 329/329 [==============================] - 22s 66ms/step - loss: 0.7982 - mae: 0.6288 - mse: 0.7982 - val_loss: 0.7676 - val_mae: 0.6557 - val_mse: 0.7676 - lr: 0.0010
# Epoch 68/100
# 328/329 [============================>.] - ETA: 0s - loss: 0.7969 - mae: 0.6266 - mse: 0.7969
# Epoch 00068: val_loss did not improve from 0.76764
# 329/329 [==============================] - 19s 59ms/step - loss: 0.7964 - mae: 0.6265 - mse: 0.7964 - val_loss: 0.8814 - val_mae: 0.7218 - val_mse: 0.8814 - lr: 0.0010
# Epoch 69/100
# 328/329 [============================>.] - ETA: 0s - loss: 0.7902 - mae: 0.6269 - mse: 0.7902
# Epoch 00069: val_loss did not improve from 0.76764
# 329/329 [==============================] - 19s 59ms/step - loss: 0.7899 - mae: 0.6269 - mse: 0.7899 - val_loss: 0.8379 - val_mae: 0.6920 - val_mse: 0.8379 - lr: 0.0010
# Epoch 70/100
# 329/329 [==============================] - ETA: 0s - loss: 0.7874 - mae: 0.6223 - mse: 0.7874
# Epoch 00070: val_loss did not improve from 0.76764
# 329/329 [==============================] - 19s 59ms/step - loss: 0.7874 - mae: 0.6223 - mse: 0.7874 - val_loss: 0.8069 - val_mae: 0.6707 - val_mse: 0.8069 - lr: 0.0010
# Epoch 71/100
# 328/329 [============================>.] - ETA: 0s - loss: 0.8029 - mae: 0.6306 - mse: 0.8029
# Epoch 00071: val_loss did not improve from 0.76764
# 329/329 [==============================] - 19s 59ms/step - loss: 0.8031 - mae: 0.6308 - mse: 0.8031 - val_loss: 0.8562 - val_mae: 0.7168 - val_mse: 0.8562 - lr: 0.0010
# Epoch 72/100
# 329/329 [==============================] - ETA: 0s - loss: 0.8041 - mae: 0.6302 - mse: 0.8041
# Epoch 00072: val_loss did not improve from 0.76764
# 329/329 [==============================] - 19s 59ms/step - loss: 0.8041 - mae: 0.6302 - mse: 0.8041 - val_loss: 0.8410 - val_mae: 0.6918 - val_mse: 0.8410 - lr: 0.0010
# Epoch 73/100
# 329/329 [==============================] - ETA: 0s - loss: 0.7865 - mae: 0.6251 - mse: 0.7865
# Epoch 00073: val_loss did not improve from 0.76764
# 329/329 [==============================] - 19s 59ms/step - loss: 0.7865 - mae: 0.6251 - mse: 0.7865 - val_loss: 0.8558 - val_mae: 0.6963 - val_mse: 0.8558 - lr: 0.0010
# Epoch 74/100
# 328/329 [============================>.] - ETA: 0s - loss: 0.7901 - mae: 0.6234 - mse: 0.7901
# Epoch 00074: val_loss did not improve from 0.76764
# 329/329 [==============================] - 19s 59ms/step - loss: 0.7904 - mae: 0.6236 - mse: 0.7904 - val_loss: 0.9231 - val_mae: 0.7271 - val_mse: 0.9231 - lr: 0.0010
# Epoch 75/100
# 329/329 [==============================] - ETA: 0s - loss: 0.7986 - mae: 0.6303 - mse: 0.7986
# Epoch 00075: val_loss improved from 0.76764 to 0.76492, saving model to ./models/H1/best_EfficientNetB5_tuning.hdf5
# 329/329 [==============================] - 22s 67ms/step - loss: 0.7986 - mae: 0.6303 - mse: 0.7986 - val_loss: 0.7649 - val_mae: 0.6535 - val_mse: 0.7649 - lr: 0.0010
# Epoch 76/100
# 328/329 [============================>.] - ETA: 0s - loss: 0.7873 - mae: 0.6229 - mse: 0.7873
# Epoch 00076: val_loss did not improve from 0.76492
# 329/329 [==============================] - 20s 59ms/step - loss: 0.7872 - mae: 0.6229 - mse: 0.7872 - val_loss: 0.8223 - val_mae: 0.6817 - val_mse: 0.8223 - lr: 0.0010
# Epoch 77/100
# 328/329 [============================>.] - ETA: 0s - loss: 0.8034 - mae: 0.6305 - mse: 0.8034
# Epoch 00077: val_loss did not improve from 0.76492
# 329/329 [==============================] - 19s 59ms/step - loss: 0.8030 - mae: 0.6304 - mse: 0.8030 - val_loss: 0.8198 - val_mae: 0.6921 - val_mse: 0.8198 - lr: 0.0010
# Epoch 78/100
# 328/329 [============================>.] - ETA: 0s - loss: 0.7850 - mae: 0.6244 - mse: 0.7850
# Epoch 00078: val_loss did not improve from 0.76492
# 329/329 [==============================] - 20s 59ms/step - loss: 0.7843 - mae: 0.6241 - mse: 0.7843 - val_loss: 0.7874 - val_mae: 0.6737 - val_mse: 0.7874 - lr: 0.0010
# Epoch 79/100
# 329/329 [==============================] - ETA: 0s - loss: 0.7910 - mae: 0.6239 - mse: 0.7910
# Epoch 00079: val_loss did not improve from 0.76492
# 329/329 [==============================] - 19s 59ms/step - loss: 0.7910 - mae: 0.6239 - mse: 0.7910 - val_loss: 1.3455 - val_mae: 0.8814 - val_mse: 1.3455 - lr: 0.0010
# Epoch 80/100
# 329/329 [==============================] - ETA: 0s - loss: 0.8004 - mae: 0.6279 - mse: 0.8004
# Epoch 00080: val_loss did not improve from 0.76492
# 329/329 [==============================] - 19s 59ms/step - loss: 0.8004 - mae: 0.6279 - mse: 0.8004 - val_loss: 1.0187 - val_mae: 0.7625 - val_mse: 1.0187 - lr: 0.0010
# Epoch 81/100
# 329/329 [==============================] - ETA: 0s - loss: 0.7898 - mae: 0.6269 - mse: 0.7898
# Epoch 00081: val_loss did not improve from 0.76492
# 329/329 [==============================] - 19s 59ms/step - loss: 0.7898 - mae: 0.6269 - mse: 0.7898 - val_loss: 0.7988 - val_mae: 0.6707 - val_mse: 0.7988 - lr: 0.0010
# Epoch 82/100
# 328/329 [============================>.] - ETA: 0s - loss: 0.7912 - mae: 0.6242 - mse: 0.7912
# Epoch 00082: val_loss did not improve from 0.76492
# 329/329 [==============================] - 19s 59ms/step - loss: 0.7929 - mae: 0.6246 - mse: 0.7929 - val_loss: 0.7979 - val_mae: 0.6826 - val_mse: 0.7979 - lr: 0.0010
# Epoch 83/100
# 329/329 [==============================] - ETA: 0s - loss: 0.7778 - mae: 0.6217 - mse: 0.7778
# Epoch 00083: val_loss did not improve from 0.76492
# 329/329 [==============================] - 19s 59ms/step - loss: 0.7778 - mae: 0.6217 - mse: 0.7778 - val_loss: 0.9024 - val_mae: 0.7205 - val_mse: 0.9024 - lr: 0.0010
# Epoch 84/100
# 329/329 [==============================] - ETA: 0s - loss: 0.7954 - mae: 0.6290 - mse: 0.7954
# Epoch 00084: val_loss did not improve from 0.76492
# 329/329 [==============================] - 19s 59ms/step - loss: 0.7954 - mae: 0.6290 - mse: 0.7954 - val_loss: 0.7832 - val_mae: 0.6655 - val_mse: 0.7832 - lr: 0.0010
# Epoch 85/100
# 328/329 [============================>.] - ETA: 0s - loss: 0.7858 - mae: 0.6223 - mse: 0.7858
# Epoch 00085: val_loss did not improve from 0.76492
# 329/329 [==============================] - 19s 59ms/step - loss: 0.7856 - mae: 0.6223 - mse: 0.7856 - val_loss: 1.0631 - val_mae: 0.7748 - val_mse: 1.0631 - lr: 0.0010
# Epoch 86/100
# 329/329 [==============================] - ETA: 0s - loss: 0.7930 - mae: 0.6237 - mse: 0.7930
# Epoch 00086: val_loss did not improve from 0.76492
# 329/329 [==============================] - 19s 59ms/step - loss: 0.7930 - mae: 0.6237 - mse: 0.7930 - val_loss: 0.7895 - val_mae: 0.6821 - val_mse: 0.7895 - lr: 0.0010
# Epoch 87/100
# 329/329 [==============================] - ETA: 0s - loss: 0.7932 - mae: 0.6252 - mse: 0.7932
# Epoch 00087: val_loss did not improve from 0.76492
# 329/329 [==============================] - 20s 60ms/step - loss: 0.7932 - mae: 0.6252 - mse: 0.7932 - val_loss: 0.8060 - val_mae: 0.6818 - val_mse: 0.8060 - lr: 0.0010
# Epoch 88/100
# 328/329 [============================>.] - ETA: 0s - loss: 0.8031 - mae: 0.6300 - mse: 0.8031
# Epoch 00088: val_loss did not improve from 0.76492
# 329/329 [==============================] - 19s 59ms/step - loss: 0.8029 - mae: 0.6300 - mse: 0.8029 - val_loss: 0.7997 - val_mae: 0.6793 - val_mse: 0.7997 - lr: 0.0010
# Epoch 89/100
# 329/329 [==============================] - ETA: 0s - loss: 0.7864 - mae: 0.6237 - mse: 0.7864
# Epoch 00089: val_loss did not improve from 0.76492
# 329/329 [==============================] - 19s 59ms/step - loss: 0.7864 - mae: 0.6237 - mse: 0.7864 - val_loss: 1.0308 - val_mae: 0.7667 - val_mse: 1.0308 - lr: 0.0010
# Epoch 90/100
# 328/329 [============================>.] - ETA: 0s - loss: 0.7813 - mae: 0.6233 - mse: 0.7813
# Epoch 00090: val_loss did not improve from 0.76492
# 329/329 [==============================] - 19s 59ms/step - loss: 0.7809 - mae: 0.6231 - mse: 0.7809 - val_loss: 1.0793 - val_mae: 0.7794 - val_mse: 1.0793 - lr: 0.0010
# Epoch 91/100
# 328/329 [============================>.] - ETA: 0s - loss: 0.7785 - mae: 0.6194 - mse: 0.7785
# Epoch 00091: val_loss did not improve from 0.76492
# 329/329 [==============================] - 19s 59ms/step - loss: 0.7781 - mae: 0.6193 - mse: 0.7781 - val_loss: 0.7851 - val_mae: 0.6398 - val_mse: 0.7851 - lr: 0.0010
# Epoch 92/100
# 328/329 [============================>.] - ETA: 0s - loss: 0.7924 - mae: 0.6269 - mse: 0.7924
# Epoch 00092: val_loss did not improve from 0.76492
# 329/329 [==============================] - 19s 59ms/step - loss: 0.7923 - mae: 0.6269 - mse: 0.7923 - val_loss: 0.7886 - val_mae: 0.6711 - val_mse: 0.7886 - lr: 0.0010
# Epoch 93/100
# 328/329 [============================>.] - ETA: 0s - loss: 0.7778 - mae: 0.6209 - mse: 0.7778
# Epoch 00093: val_loss did not improve from 0.76492
# 329/329 [==============================] - 19s 59ms/step - loss: 0.7788 - mae: 0.6213 - mse: 0.7788 - val_loss: 0.7720 - val_mae: 0.6598 - val_mse: 0.7720 - lr: 0.0010
# Epoch 94/100
# 328/329 [============================>.] - ETA: 0s - loss: 0.7790 - mae: 0.6204 - mse: 0.7790
# Epoch 00094: val_loss did not improve from 0.76492
# 329/329 [==============================] - 20s 59ms/step - loss: 0.7792 - mae: 0.6205 - mse: 0.7792 - val_loss: 0.7922 - val_mae: 0.6865 - val_mse: 0.7922 - lr: 0.0010
# Epoch 95/100
# 328/329 [============================>.] - ETA: 0s - loss: 0.7839 - mae: 0.6233 - mse: 0.7839
# Epoch 00095: ReduceLROnPlateau reducing learning rate to 0.00020000000949949026.
#
# Epoch 00095: val_loss did not improve from 0.76492
# 329/329 [==============================] - 19s 59ms/step - loss: 0.7850 - mae: 0.6235 - mse: 0.7850 - val_loss: 1.0716 - val_mae: 0.8119 - val_mse: 1.0716 - lr: 0.0010
# Epoch 00095: early stopping
# 329/329 [==============================] - 8s 25ms/step
# MAE 0.8119, MSE 1.0716, RMSE 1.0352, MAPE 368.2969
