# %%
from google.colab import drive
drive.mount('/content/drive/')
# %cd /content/drive/My\ Drive/Colab\ Notebooks\

# from tensorflow.keras.applications.vgg19 import VGG19
# from tensorflow.keras.applications.mobilenet_v2  import MobileNetV2
# from tensorflow.keras.applications.nasnet import NASNetLarge 
# from tensorflow.keras.applications.xception import Xception
# from tensorflow.keras.applications.resnet50 import ResNet50
# from tensorflow.keras.applications.resnet import ResNet101
# from tensorflow.keras.applications.resnet import ResNet152
# from tensorflow.keras.applications.resnet_v2 import ResNet50V2
# from tensorflow.keras.applications.resnet_v2 import ResNet101V2
# from tensorflow.keras.applications.resnet_v2 import ResNet152V2
# from tensorflow.keras.applications.inception_v3 import InceptionV3
# from tensorflow.keras.applications.inception_resnet_v2 import InceptionResNetV2	
# from tensorflow.keras.applications.mobilenet import MobileNet
# from tensorflow.keras.applications.densenet import DenseNet121
# from tensorflow.keras.applications.densenet import DenseNet169
# from tensorflow.keras.applications.densenet import DenseNet201
# from tensorflow.keras.applications.nasnet import NASNetMobile
# from tensorflow.keras.applications.nasnet import NASNetLarge
from tensorflow.python.keras.applications.efficientnet import EfficientNetB0
# from tensorflow.python.keras.applications.efficientnets import EfficientNetB0
# from tensorflow.python.keras.applications.efficientnets import EfficientNetB1
# from tensorflow.python.keras.applications.efficientnets import EfficientNetB2
# from tensorflow.python.keras.applications.efficientnets import EfficientNetB3
# from tensorflow.python.keras.applications.efficientnets import EfficientNetB4
# from tensorflow.python.keras.applications.efficientnets import EfficientNetB5
# from tensorflow.python.keras.applications.efficientnets import EfficientNetB6
# from tensorflow.python.keras.applications.efficientnets import EfficientNetB7
from tensorflow.keras.layers import Input, Dropout
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Dense, GlobalAveragePooling2D
import numpy as np
from keras.utils import to_categorical
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint
from tensorflow.keras.callbacks import ReduceLROnPlateau
from tensorflow.keras.optimizers import Adam, RMSprop 
# !pip install keras-adamw
# from keras_adamw import AdamW
import os
from sklearn.utils import shuffle
from keras.utils import np_utils
import scipy.io as sio

# filename = 'NASNetLarge_tuning' 
# filename = 'Xception_tuning'
# filename = 'mobilenetV2_tuning'
# filename = 'ResNet50_tuning'
# filename = 'ResNet101_tuning'
# filename = 'ResNet152_tuning'
# filename = 'ResNet50V2_tuning' 
# filename = 'ResNet101V2_tuning' 
# filename = 'ResNet152V2_tuning' 
# filename = 'InceptionV3_tuning' 
# filename = 'InceptionResNetV2_tuning' 
# filename = 'MobileNet_tuning' 
# filename = 'DenseNet121_tuning' 
# filename = 'DenseNet169_tuning' 
# filename = 'DenseNet201_tuning' 
# filename = 'NASNetMobile_tuning' 
filename = 'EfficientNetB0_tuning'
#=============================================================================
print('Loading data...')
ExType = 'H1'
DataPath = './wind_data/Norm_Train_Val_data_Lag10_'+ExType+'.mat'   
train_data = sio.loadmat(DataPath)['XTrain']#[...,np.newaxis]
train_labels = sio.loadmat(DataPath)['YTrain']
train_labels = np.squeeze(train_labels)
valid_data = sio.loadmat(DataPath)['XVal']#[...,np.newaxis]
valid_labels = sio.loadmat(DataPath)['YVal']
valid_labels = np.squeeze(valid_labels)

print('Wind Train data dim.   (samples x lag x parameters)',train_data.shape)
print('Wind Train labels dim. (samples x lag x parameters)',train_labels.shape)
print('Wind Valid dim.        (samples x lag x parameters)',valid_data.shape)
print('Wind Valid labels dim. (samples x lag x parameters)',valid_labels.shape)

# data resizing
resizeTo = 32
from tensorflow.keras.preprocessing.image import array_to_img
train_images = np.zeros((train_data.shape[0],resizeTo,resizeTo))
for i, im in enumerate(train_data):
  a = array_to_img(train_data[i,:, :, np.newaxis])
  train_images[i,...] = np.array(a.resize((resizeTo,resizeTo)))
valid_images = np.zeros((valid_data.shape[0],resizeTo,resizeTo))
for i, im in enumerate(valid_data):
  a = array_to_img(valid_data[i,:, :, np.newaxis])
  valid_images[i,...] = np.array(a.resize((resizeTo,resizeTo)))


# duplicate the data three times to look like rgb image
train_data = np.repeat(train_images[:, :, :, np.newaxis], 3, axis=3)
valid_data = np.repeat(valid_images[:, :, :, np.newaxis], 3, axis=3)
print('Wind Train images dim.   (samples x lag x parameters x channels)',train_data.shape)
#=============================================================================
    

base_model = EfficientNetB0(weights='imagenet', include_top=False,
                      input_tensor=Input(shape=(train_data.shape[1],train_data.shape[2],3)))# new input shape 


noLayers = len(base_model.layers)
# add a global spatial average pooling layer
x = base_model.output
x = GlobalAveragePooling2D()(x)
# let's add a fully-connected layer
x = Dense(1024, activation='relu')(x)
x = Dropout(rate=0.2)(x)
x = Dense(512, activation='relu')(x)
x = Dropout(rate=0.2)(x)
# x = Dense(256, activation='relu')(x)
# and a logistic layer -- let's say we have 200 classes
predictions = Dense(1, activation='linear')(x)

# this is the model we will train
model = Model(inputs=base_model.input, outputs=predictions)

# first: train only the top layers (which were randomly initialized)
# i.e. freeze all convolutional InceptionV3 layers
# for layer in base_model.layers[:noLayers]:
#     layer.trainable = False

#second: fine tune all layers with small learning rate
# Unfreeze the base model
base_model.trainable = False
# print(model.summary())
# compile the model (should be done *after* setting layers to non-trainable)
optimizer = Adam(lr=1e-03, beta_1=0.9, beta_2=0.999, epsilon=1e-08, decay=1e-06, amsgrad=False)
# optimizer = RMSprop(learning_rate=0.001, rho=0.9, momentum=0.9, epsilon=1e-07)
# optimizer = AdamW(lr=1e-4, model=model)
model.compile(optimizer=optimizer, loss='mse',metrics=['mae','mse'])

saveTo = './models/'+ExType
if not os.path.exists(saveTo):
    os.makedirs(saveTo)
    
callbacks=[ReduceLROnPlateau(monitor='val_loss', factor=0.2, patience=20, 
            verbose=1, mode='auto', min_delta=0.0005, min_lr=1e-07),#0.0001
            EarlyStopping(monitor='val_loss', patience=20, verbose=1, mode='auto'),
            ModelCheckpoint(saveTo + '/best_'+filename+'.hdf5', monitor='val_loss', verbose=1, 
                            save_best_only=True, mode='auto')]

model.fit(train_data,train_labels,
          batch_size=128,
          epochs=100,
          shuffle=True,
          validation_data=(valid_data,valid_labels),
          verbose=1,
          callbacks=callbacks)
# Testing
# from sklearn.metrics import confusion_matrix
# import sklearn.metrics as skm
import matplotlib.pyplot as plt
from sklearn.metrics import mean_squared_error, mean_absolute_error
from math import sqrt

predictions = model.predict(valid_data,verbose=1)
# MAPE = np.mean(100*2.0 * np.abs(valid_labels - predictions) / (np.abs(valid_labels) + np.abs(predictions))).item()
MAPE = np.mean(np.abs((valid_labels - predictions) / valid_labels)) * 100
print("MAE {:.4}, MSE {:.4f}, RMSE {:.4f}, MAPE {:.4f}".format(
    mean_absolute_error(valid_labels, predictions),
    mean_squared_error(valid_labels, predictions),
    sqrt(mean_squared_error(valid_labels, predictions)),
    MAPE))
plt.scatter(valid_labels,predictions)
plt.figure(figsize=(30,6)); 
plt.plot(valid_labels, label='true')
plt.plot(predictions, label='pred')
plt.legend()
# Out:
# Drive already mounted at /content/drive/; to attempt to forcibly remount, call drive.mount("/content/drive/", force_remount=True).
# /content/drive/My Drive/Colab Notebooks
# Using TensorFlow backend.
# Loading data...
# Wind Train data dim.   (samples x lag x parameters) (42039, 10, 10)
# Wind Train labels dim. (samples x lag x parameters) (42039,)
# Wind Valid dim.        (samples x lag x parameters) (10502, 10, 10)
# Wind Valid labels dim. (samples x lag x parameters) (10502,)
# Wind Train images dim.   (samples x lag x parameters x channels) (42039, 32, 32, 3)
# Downloading data from https://storage.googleapis.com/keras-applications/efficientnetb0_notop.h5
# 16711680/16705208 [==============================] - 0s 0us/step
# Epoch 1/100
# 329/329 [==============================] - ETA: 0s - loss: 0.7607 - mae: 0.6178 - mse: 0.7607
# Epoch 00001: val_loss improved from inf to 0.78795, saving model to ./models/H1/best_EfficientNetB0_tuning.hdf5
# 329/329 [==============================] - 8s 25ms/step - loss: 0.7607 - mae: 0.6178 - mse: 0.7607 - val_loss: 0.7879 - val_mae: 0.7094 - val_mse: 0.7879 - lr: 0.0010
# Epoch 2/100
# 328/329 [============================>.] - ETA: 0s - loss: 0.5777 - mae: 0.5453 - mse: 0.5777
# Epoch 00002: val_loss improved from 0.78795 to 0.75503, saving model to ./models/H1/best_EfficientNetB0_tuning.hdf5
# 329/329 [==============================] - 7s 20ms/step - loss: 0.5775 - mae: 0.5453 - mse: 0.5775 - val_loss: 0.7550 - val_mae: 0.6172 - val_mse: 0.7550 - lr: 0.0010
# Epoch 3/100
# 329/329 [==============================] - ETA: 0s - loss: 0.5233 - mae: 0.5203 - mse: 0.5233
# Epoch 00003: val_loss improved from 0.75503 to 0.58824, saving model to ./models/H1/best_EfficientNetB0_tuning.hdf5
# 329/329 [==============================] - 7s 20ms/step - loss: 0.5233 - mae: 0.5203 - mse: 0.5233 - val_loss: 0.5882 - val_mae: 0.6011 - val_mse: 0.5882 - lr: 0.0010
# Epoch 4/100
# 327/329 [============================>.] - ETA: 0s - loss: 0.4928 - mae: 0.5053 - mse: 0.4928
# Epoch 00004: val_loss improved from 0.58824 to 0.53589, saving model to ./models/H1/best_EfficientNetB0_tuning.hdf5
# 329/329 [==============================] - 7s 20ms/step - loss: 0.4922 - mae: 0.5051 - mse: 0.4922 - val_loss: 0.5359 - val_mae: 0.5451 - val_mse: 0.5359 - lr: 0.0010
# Epoch 5/100
# 329/329 [==============================] - ETA: 0s - loss: 0.5006 - mae: 0.5074 - mse: 0.5006
# Epoch 00005: val_loss did not improve from 0.53589
# 329/329 [==============================] - 6s 19ms/step - loss: 0.5006 - mae: 0.5074 - mse: 0.5006 - val_loss: 0.5511 - val_mae: 0.5434 - val_mse: 0.5511 - lr: 0.0010
# Epoch 6/100
# 329/329 [==============================] - ETA: 0s - loss: 0.4784 - mae: 0.4961 - mse: 0.4784
# Epoch 00006: val_loss improved from 0.53589 to 0.48932, saving model to ./models/H1/best_EfficientNetB0_tuning.hdf5
# 329/329 [==============================] - 7s 22ms/step - loss: 0.4784 - mae: 0.4961 - mse: 0.4784 - val_loss: 0.4893 - val_mae: 0.5170 - val_mse: 0.4893 - lr: 0.0010
# Epoch 7/100
# 326/329 [============================>.] - ETA: 0s - loss: 0.4577 - mae: 0.4860 - mse: 0.4577
# Epoch 00007: val_loss did not improve from 0.48932
# 329/329 [==============================] - 6s 19ms/step - loss: 0.4575 - mae: 0.4857 - mse: 0.4575 - val_loss: 0.4933 - val_mae: 0.5194 - val_mse: 0.4933 - lr: 0.0010
# Epoch 8/100
# 326/329 [============================>.] - ETA: 0s - loss: 0.4470 - mae: 0.4828 - mse: 0.4470
# Epoch 00008: val_loss did not improve from 0.48932
# 329/329 [==============================] - 6s 19ms/step - loss: 0.4470 - mae: 0.4827 - mse: 0.4470 - val_loss: 0.5402 - val_mae: 0.5375 - val_mse: 0.5402 - lr: 0.0010
# Epoch 9/100
# 328/329 [============================>.] - ETA: 0s - loss: 0.4608 - mae: 0.4884 - mse: 0.4608
# Epoch 00009: val_loss did not improve from 0.48932
# 329/329 [==============================] - 6s 19ms/step - loss: 0.4611 - mae: 0.4884 - mse: 0.4611 - val_loss: 0.7130 - val_mae: 0.6306 - val_mse: 0.7130 - lr: 0.0010
# Epoch 10/100
# 328/329 [============================>.] - ETA: 0s - loss: 0.4670 - mae: 0.4902 - mse: 0.4670
# Epoch 00010: val_loss did not improve from 0.48932
# 329/329 [==============================] - 6s 18ms/step - loss: 0.4669 - mae: 0.4902 - mse: 0.4669 - val_loss: 0.5173 - val_mae: 0.5195 - val_mse: 0.5173 - lr: 0.0010
# Epoch 11/100
# 328/329 [============================>.] - ETA: 0s - loss: 0.4532 - mae: 0.4842 - mse: 0.4532
# Epoch 00011: val_loss did not improve from 0.48932
# 329/329 [==============================] - 6s 18ms/step - loss: 0.4533 - mae: 0.4842 - mse: 0.4533 - val_loss: 0.5516 - val_mae: 0.5303 - val_mse: 0.5516 - lr: 0.0010
# Epoch 12/100
# 327/329 [============================>.] - ETA: 0s - loss: 0.4469 - mae: 0.4808 - mse: 0.4469
# Epoch 00012: val_loss did not improve from 0.48932
# 329/329 [==============================] - 6s 18ms/step - loss: 0.4465 - mae: 0.4808 - mse: 0.4465 - val_loss: 0.5105 - val_mae: 0.5332 - val_mse: 0.5105 - lr: 0.0010
# Epoch 13/100
# 327/329 [============================>.] - ETA: 0s - loss: 0.4318 - mae: 0.4738 - mse: 0.4318
# Epoch 00013: val_loss did not improve from 0.48932
# 329/329 [==============================] - 6s 18ms/step - loss: 0.4319 - mae: 0.4738 - mse: 0.4319 - val_loss: 0.5301 - val_mae: 0.5241 - val_mse: 0.5301 - lr: 0.0010
# Epoch 14/100
# 328/329 [============================>.] - ETA: 0s - loss: 0.4425 - mae: 0.4784 - mse: 0.4425
# Epoch 00014: val_loss did not improve from 0.48932
# 329/329 [==============================] - 6s 18ms/step - loss: 0.4434 - mae: 0.4787 - mse: 0.4434 - val_loss: 0.5707 - val_mae: 0.5378 - val_mse: 0.5707 - lr: 0.0010
# Epoch 15/100
# 329/329 [==============================] - ETA: 0s - loss: 0.4389 - mae: 0.4792 - mse: 0.4389
# Epoch 00015: val_loss did not improve from 0.48932
# 329/329 [==============================] - 6s 18ms/step - loss: 0.4389 - mae: 0.4792 - mse: 0.4389 - val_loss: 0.5414 - val_mae: 0.5244 - val_mse: 0.5414 - lr: 0.0010
# Epoch 16/100
# 328/329 [============================>.] - ETA: 0s - loss: 0.4388 - mae: 0.4755 - mse: 0.4388
# Epoch 00016: val_loss did not improve from 0.48932
# 329/329 [==============================] - 6s 18ms/step - loss: 0.4386 - mae: 0.4754 - mse: 0.4386 - val_loss: 0.5449 - val_mae: 0.5236 - val_mse: 0.5449 - lr: 0.0010
# Epoch 17/100
# 329/329 [==============================] - ETA: 0s - loss: 0.4375 - mae: 0.4758 - mse: 0.4375
# Epoch 00017: val_loss did not improve from 0.48932
# 329/329 [==============================] - 6s 18ms/step - loss: 0.4375 - mae: 0.4758 - mse: 0.4375 - val_loss: 0.5104 - val_mae: 0.5256 - val_mse: 0.5104 - lr: 0.0010
# Epoch 18/100
# 329/329 [==============================] - ETA: 0s - loss: 0.4323 - mae: 0.4731 - mse: 0.4323
# Epoch 00018: val_loss improved from 0.48932 to 0.46170, saving model to ./models/H1/best_EfficientNetB0_tuning.hdf5
# 329/329 [==============================] - 7s 22ms/step - loss: 0.4323 - mae: 0.4731 - mse: 0.4323 - val_loss: 0.4617 - val_mae: 0.4904 - val_mse: 0.4617 - lr: 0.0010
# Epoch 19/100
# 327/329 [============================>.] - ETA: 0s - loss: 0.4268 - mae: 0.4724 - mse: 0.4268
# Epoch 00019: val_loss did not improve from 0.46170
# 329/329 [==============================] - 6s 19ms/step - loss: 0.4266 - mae: 0.4724 - mse: 0.4266 - val_loss: 0.5132 - val_mae: 0.5171 - val_mse: 0.5132 - lr: 0.0010
# Epoch 20/100
# 327/329 [============================>.] - ETA: 0s - loss: 0.4340 - mae: 0.4725 - mse: 0.4340
# Epoch 00020: val_loss did not improve from 0.46170
# 329/329 [==============================] - 6s 19ms/step - loss: 0.4338 - mae: 0.4725 - mse: 0.4338 - val_loss: 0.5631 - val_mae: 0.5333 - val_mse: 0.5631 - lr: 0.0010
# Epoch 21/100
# 327/329 [============================>.] - ETA: 0s - loss: 0.4233 - mae: 0.4678 - mse: 0.4233
# Epoch 00021: val_loss did not improve from 0.46170
# 329/329 [==============================] - 6s 18ms/step - loss: 0.4227 - mae: 0.4675 - mse: 0.4227 - val_loss: 0.5556 - val_mae: 0.5223 - val_mse: 0.5556 - lr: 0.0010
# Epoch 22/100
# 328/329 [============================>.] - ETA: 0s - loss: 0.4247 - mae: 0.4691 - mse: 0.4247
# Epoch 00022: val_loss did not improve from 0.46170
# 329/329 [==============================] - 6s 18ms/step - loss: 0.4246 - mae: 0.4691 - mse: 0.4246 - val_loss: 0.4960 - val_mae: 0.5415 - val_mse: 0.4960 - lr: 0.0010
# Epoch 23/100
# 329/329 [==============================] - ETA: 0s - loss: 0.4216 - mae: 0.4659 - mse: 0.4216
# Epoch 00023: val_loss did not improve from 0.46170
# 329/329 [==============================] - 6s 18ms/step - loss: 0.4216 - mae: 0.4659 - mse: 0.4216 - val_loss: 0.4864 - val_mae: 0.5105 - val_mse: 0.4864 - lr: 0.0010
# Epoch 24/100
# 328/329 [============================>.] - ETA: 0s - loss: 0.4121 - mae: 0.4632 - mse: 0.4121
# Epoch 00024: val_loss did not improve from 0.46170
# 329/329 [==============================] - 6s 19ms/step - loss: 0.4121 - mae: 0.4632 - mse: 0.4121 - val_loss: 0.5123 - val_mae: 0.5179 - val_mse: 0.5123 - lr: 0.0010
# Epoch 25/100
# 329/329 [==============================] - ETA: 0s - loss: 0.4327 - mae: 0.4728 - mse: 0.4327
# Epoch 00025: val_loss did not improve from 0.46170
# 329/329 [==============================] - 6s 18ms/step - loss: 0.4327 - mae: 0.4728 - mse: 0.4327 - val_loss: 0.4752 - val_mae: 0.5076 - val_mse: 0.4752 - lr: 0.0010
# Epoch 26/100
# 328/329 [============================>.] - ETA: 0s - loss: 0.4241 - mae: 0.4686 - mse: 0.4241
# Epoch 00026: val_loss did not improve from 0.46170
# 329/329 [==============================] - 6s 18ms/step - loss: 0.4240 - mae: 0.4685 - mse: 0.4240 - val_loss: 0.5287 - val_mae: 0.5110 - val_mse: 0.5287 - lr: 0.0010
# Epoch 27/100
# 329/329 [==============================] - ETA: 0s - loss: 0.4101 - mae: 0.4615 - mse: 0.4101
# Epoch 00027: val_loss did not improve from 0.46170
# 329/329 [==============================] - 6s 18ms/step - loss: 0.4101 - mae: 0.4615 - mse: 0.4101 - val_loss: 0.5230 - val_mae: 0.5318 - val_mse: 0.5230 - lr: 0.0010
# Epoch 28/100
# 327/329 [============================>.] - ETA: 0s - loss: 0.4144 - mae: 0.4647 - mse: 0.4144
# Epoch 00028: val_loss did not improve from 0.46170
# 329/329 [==============================] - 6s 18ms/step - loss: 0.4147 - mae: 0.4649 - mse: 0.4147 - val_loss: 0.5152 - val_mae: 0.5440 - val_mse: 0.5152 - lr: 0.0010
# Epoch 29/100
# 327/329 [============================>.] - ETA: 0s - loss: 0.4126 - mae: 0.4640 - mse: 0.4126
# Epoch 00029: val_loss did not improve from 0.46170
# 329/329 [==============================] - 6s 18ms/step - loss: 0.4128 - mae: 0.4641 - mse: 0.4128 - val_loss: 0.5644 - val_mae: 0.5426 - val_mse: 0.5644 - lr: 0.0010
# Epoch 30/100
# 328/329 [============================>.] - ETA: 0s - loss: 0.4292 - mae: 0.4760 - mse: 0.4292
# Epoch 00030: val_loss did not improve from 0.46170
# 329/329 [==============================] - 6s 18ms/step - loss: 0.4292 - mae: 0.4760 - mse: 0.4292 - val_loss: 0.4866 - val_mae: 0.4887 - val_mse: 0.4866 - lr: 0.0010
# Epoch 31/100
# 329/329 [==============================] - ETA: 0s - loss: 0.4022 - mae: 0.4577 - mse: 0.4022
# Epoch 00031: val_loss did not improve from 0.46170
# 329/329 [==============================] - 6s 19ms/step - loss: 0.4022 - mae: 0.4577 - mse: 0.4022 - val_loss: 0.4685 - val_mae: 0.4897 - val_mse: 0.4685 - lr: 0.0010
# Epoch 32/100
# 328/329 [============================>.] - ETA: 0s - loss: 0.4102 - mae: 0.4606 - mse: 0.4102
# Epoch 00032: val_loss did not improve from 0.46170
# 329/329 [==============================] - 6s 19ms/step - loss: 0.4108 - mae: 0.4609 - mse: 0.4108 - val_loss: 0.4936 - val_mae: 0.5138 - val_mse: 0.4936 - lr: 0.0010
# Epoch 33/100
# 328/329 [============================>.] - ETA: 0s - loss: 0.3959 - mae: 0.4526 - mse: 0.3959
# Epoch 00033: val_loss did not improve from 0.46170
# 329/329 [==============================] - 6s 19ms/step - loss: 0.3959 - mae: 0.4527 - mse: 0.3959 - val_loss: 0.4930 - val_mae: 0.5162 - val_mse: 0.4930 - lr: 0.0010
# Epoch 34/100
# 329/329 [==============================] - ETA: 0s - loss: 0.4084 - mae: 0.4599 - mse: 0.4084
# Epoch 00034: val_loss did not improve from 0.46170
# 329/329 [==============================] - 6s 19ms/step - loss: 0.4084 - mae: 0.4599 - mse: 0.4084 - val_loss: 0.5150 - val_mae: 0.5244 - val_mse: 0.5150 - lr: 0.0010
# Epoch 35/100
# 327/329 [============================>.] - ETA: 0s - loss: 0.4161 - mae: 0.4643 - mse: 0.4161
# Epoch 00035: val_loss did not improve from 0.46170
# 329/329 [==============================] - 6s 19ms/step - loss: 0.4157 - mae: 0.4640 - mse: 0.4157 - val_loss: 0.4937 - val_mae: 0.5230 - val_mse: 0.4937 - lr: 0.0010
# Epoch 36/100
# 328/329 [============================>.] - ETA: 0s - loss: 0.4100 - mae: 0.4604 - mse: 0.4100
# Epoch 00036: val_loss did not improve from 0.46170
# 329/329 [==============================] - 6s 18ms/step - loss: 0.4102 - mae: 0.4605 - mse: 0.4102 - val_loss: 0.4660 - val_mae: 0.5030 - val_mse: 0.4660 - lr: 0.0010
# Epoch 37/100
# 329/329 [==============================] - ETA: 0s - loss: 0.4038 - mae: 0.4584 - mse: 0.4038
# Epoch 00037: val_loss did not improve from 0.46170
# 329/329 [==============================] - 6s 19ms/step - loss: 0.4038 - mae: 0.4584 - mse: 0.4038 - val_loss: 0.5327 - val_mae: 0.5411 - val_mse: 0.5327 - lr: 0.0010
# Epoch 38/100
# 329/329 [==============================] - ETA: 0s - loss: 0.4068 - mae: 0.4576 - mse: 0.4068
# Epoch 00038: ReduceLROnPlateau reducing learning rate to 0.00020000000949949026.
#
# Epoch 00038: val_loss did not improve from 0.46170
# 329/329 [==============================] - 6s 18ms/step - loss: 0.4068 - mae: 0.4576 - mse: 0.4068 - val_loss: 0.5172 - val_mae: 0.5267 - val_mse: 0.5172 - lr: 0.0010
# Epoch 00038: early stopping
# 329/329 [==============================] - 3s 8ms/step
# MAE 0.5267, MSE 0.5172, RMSE 0.7191, MAPE 274.4535
