# %%
from google.colab import drive
drive.mount('/content/drive/')
# %cd /content/drive/My\ Drive/Colab\ Notebooks\

# from tensorflow.keras.applications.mobilenet_v2  import MobileNetV2
# from tensorflow.keras.applications.nasnet import NASNetLarge 
# from tensorflow.keras.applications.xception import Xception
from tensorflow.keras.applications.resnet50 import ResNet50
# from tensorflow.keras.applications.vgg19 import VGG19
from tensorflow.keras.layers import Input, Dropout
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Dense, GlobalAveragePooling2D
import numpy as np
from keras.utils import to_categorical
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint
from tensorflow.keras.callbacks import ReduceLROnPlateau
from tensorflow.keras.optimizers import Adam, RMSprop 
# !pip install keras-adamw
# from keras_adamw import AdamW
import os
from sklearn.utils import shuffle
from keras.utils import np_utils
import scipy.io as sio

# filename = 'NASNetLarge_tuning' 
filename = 'Xception_tuning'
# filename = 'mobilenetV2_tuning'
filename = 'ResNet50_tuning'

#=============================================================================
print('Loading data...')
ExType = 'H18'
DataPath = './wind_data/Norm_Train_Val_data_Lag10_'+ExType+'.mat'   
train_data = sio.loadmat(DataPath)['XTrain']#[...,np.newaxis]
train_labels = sio.loadmat(DataPath)['YTrain']
train_labels = np.squeeze(train_labels)
valid_data = sio.loadmat(DataPath)['XVal']#[...,np.newaxis]
valid_labels = sio.loadmat(DataPath)['YVal']
valid_labels = np.squeeze(valid_labels)

print('Wind Train data dim.   (samples x lag x parameters)',train_data.shape)
print('Wind Train labels dim. (samples x lag x parameters)',train_labels.shape)
print('Wind Valid dim.        (samples x lag x parameters)',valid_data.shape)
print('Wind Valid labels dim. (samples x lag x parameters)',valid_labels.shape)

# data resizing
from tensorflow.keras.preprocessing.image import array_to_img
train_images = np.zeros((train_data.shape[0],32,32))
for i, im in enumerate(train_data):
  a = array_to_img(train_data[i,:, :, np.newaxis])
  train_images[i,...] = np.array(a.resize((32,32)))
valid_images = np.zeros((valid_data.shape[0],32,32))
for i, im in enumerate(valid_data):
  a = array_to_img(valid_data[i,:, :, np.newaxis])
  valid_images[i,...] = np.array(a.resize((32,32)))


# duplicate the data three times to look like rgb image
train_data = np.repeat(train_images[:, :, :, np.newaxis], 3, axis=3)
valid_data = np.repeat(valid_images[:, :, :, np.newaxis], 3, axis=3)
print('Wind Train images dim.   (samples x lag x parameters x channels)',train_data.shape)
#=============================================================================
    

base_model = ResNet50(weights='imagenet', include_top=False,
                      input_tensor=Input(shape=(train_data.shape[1],train_data.shape[2],3)))# new input shape 


noLayers = len(base_model.layers)
# add a global spatial average pooling layer
x = base_model.output
x = GlobalAveragePooling2D()(x)
# let's add a fully-connected layer
x = Dense(1024, activation='relu')(x)
x = Dropout(rate=0.2)(x)
x = Dense(512, activation='relu')(x)
x = Dropout(rate=0.2)(x)
# x = Dense(256, activation='relu')(x)
# and a logistic layer -- let's say we have 200 classes
predictions = Dense(1, activation='linear')(x)

# this is the model we will train
model = Model(inputs=base_model.input, outputs=predictions)

# first: train only the top layers (which were randomly initialized)
# i.e. freeze all convolutional InceptionV3 layers
# for layer in base_model.layers[:noLayers]:
#     layer.trainable = False

#second: fine tune all layers with small learning rate
# Unfreeze the base model
base_model.trainable = False
# print(model.summary())
# compile the model (should be done *after* setting layers to non-trainable)
optimizer = Adam(lr=1e-03, beta_1=0.9, beta_2=0.999, epsilon=1e-08, decay=1e-06, amsgrad=False)
# optimizer = RMSprop(learning_rate=0.001, rho=0.9, momentum=0.9, epsilon=1e-07)
# optimizer = AdamW(lr=1e-4, model=model)
model.compile(optimizer=optimizer, loss='mse',metrics=['mae','mse'])

saveTo = './models/'+ExType
if not os.path.exists(saveTo):
    os.makedirs(saveTo)
    
callbacks=[ReduceLROnPlateau(monitor='val_loss', factor=0.2, patience=20, 
            verbose=1, mode='auto', min_delta=0.0005, min_lr=1e-07),#0.0001
            EarlyStopping(monitor='val_loss', patience=20, verbose=1, mode='auto'),
            ModelCheckpoint(saveTo + '/best_'+filename+'.hdf5', monitor='val_loss', verbose=1, 
                            save_best_only=True, mode='auto')]

model.fit(train_data,train_labels,
          batch_size=128,
          epochs=100,
          shuffle=True,
          validation_data=(valid_data,valid_labels),
          verbose=1,
          callbacks=callbacks)
# Testing
# from sklearn.metrics import confusion_matrix
# import sklearn.metrics as skm
import matplotlib.pyplot as plt
from sklearn.metrics import mean_squared_error, mean_absolute_error
from math import sqrt

predictions = model.predict(valid_data,verbose=1)
# MAPE = np.mean(100*2.0 * np.abs(valid_labels - predictions) / (np.abs(valid_labels) + np.abs(predictions))).item()
MAPE = np.mean(np.abs((valid_labels - predictions) / valid_labels)) * 100
print("MAE {:.4}, MSE {:.4f}, RMSE {:.4f}, MAPE {:.4f}".format(
    mean_absolute_error(valid_labels, predictions),
    mean_squared_error(valid_labels, predictions),
    sqrt(mean_squared_error(valid_labels, predictions)),
    MAPE))
plt.scatter(valid_labels,predictions)
plt.figure(figsize=(30,6)); 
plt.plot(valid_labels, label='true')
plt.plot(predictions, label='pred')
plt.legend()
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive/
# /content/drive/My Drive/Colab Notebooks
# Using TensorFlow backend.
# Loading data...
# Wind Train data dim.   (samples x lag x parameters) (42022, 10, 10)
# Wind Train labels dim. (samples x lag x parameters) (42022,)
# Wind Valid dim.        (samples x lag x parameters) (10485, 10, 10)
# Wind Valid labels dim. (samples x lag x parameters) (10485,)
# Wind Train images dim.   (samples x lag x parameters x channels) (42022, 32, 32, 3)
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/resnet/resnet50_weights_tf_dim_ordering_tf_kernels_notop.h5
# 94773248/94765736 [==============================] - 1s 0us/step
# Epoch 1/100
# 329/329 [==============================] - ETA: 0s - loss: 5.2372 - mae: 0.9260 - mse: 5.2372
# Epoch 00001: val_loss improved from inf to 0.84828, saving model to ./models/H18/best_ResNet50_tuning.hdf5
# 329/329 [==============================] - 8s 25ms/step - loss: 5.2372 - mae: 0.9260 - mse: 5.2372 - val_loss: 0.8483 - val_mae: 0.7058 - val_mse: 0.8483 - lr: 0.0010
# Epoch 2/100
# 329/329 [==============================] - ETA: 0s - loss: 0.7579 - mae: 0.6070 - mse: 0.7579
# Epoch 00002: val_loss improved from 0.84828 to 0.84809, saving model to ./models/H18/best_ResNet50_tuning.hdf5
# 329/329 [==============================] - 7s 22ms/step - loss: 0.7579 - mae: 0.6070 - mse: 0.7579 - val_loss: 0.8481 - val_mae: 0.6904 - val_mse: 0.8481 - lr: 0.0010
# Epoch 3/100
# 327/329 [============================>.] - ETA: 0s - loss: 0.7186 - mae: 0.5928 - mse: 0.7186
# Epoch 00003: val_loss improved from 0.84809 to 0.82900, saving model to ./models/H18/best_ResNet50_tuning.hdf5
# 329/329 [==============================] - 7s 22ms/step - loss: 0.7174 - mae: 0.5924 - mse: 0.7174 - val_loss: 0.8290 - val_mae: 0.6831 - val_mse: 0.8290 - lr: 0.0010
# Epoch 4/100
# 326/329 [============================>.] - ETA: 0s - loss: 0.6966 - mae: 0.5841 - mse: 0.6966
# Epoch 00004: val_loss did not improve from 0.82900
# 329/329 [==============================] - 6s 20ms/step - loss: 0.6960 - mae: 0.5839 - mse: 0.6960 - val_loss: 0.8393 - val_mae: 0.6581 - val_mse: 0.8393 - lr: 0.0010
# Epoch 5/100
# 327/329 [============================>.] - ETA: 0s - loss: 0.6783 - mae: 0.5768 - mse: 0.6783
# Epoch 00005: val_loss improved from 0.82900 to 0.80969, saving model to ./models/H18/best_ResNet50_tuning.hdf5
# 329/329 [==============================] - 8s 24ms/step - loss: 0.6786 - mae: 0.5769 - mse: 0.6786 - val_loss: 0.8097 - val_mae: 0.6692 - val_mse: 0.8097 - lr: 0.0010
# Epoch 6/100
# 326/329 [============================>.] - ETA: 0s - loss: 0.6600 - mae: 0.5693 - mse: 0.6600
# Epoch 00006: val_loss did not improve from 0.80969
# 329/329 [==============================] - 6s 19ms/step - loss: 0.6593 - mae: 0.5691 - mse: 0.6593 - val_loss: 0.8485 - val_mae: 0.6603 - val_mse: 0.8485 - lr: 0.0010
# Epoch 7/100
# 328/329 [============================>.] - ETA: 0s - loss: 0.6484 - mae: 0.5646 - mse: 0.6484
# Epoch 00007: val_loss did not improve from 0.80969
# 329/329 [==============================] - 6s 19ms/step - loss: 0.6488 - mae: 0.5647 - mse: 0.6488 - val_loss: 0.8339 - val_mae: 0.6579 - val_mse: 0.8339 - lr: 0.0010
# Epoch 8/100
# 329/329 [==============================] - ETA: 0s - loss: 0.6399 - mae: 0.5596 - mse: 0.6399
# Epoch 00008: val_loss did not improve from 0.80969
# 329/329 [==============================] - 6s 19ms/step - loss: 0.6399 - mae: 0.5596 - mse: 0.6399 - val_loss: 0.8713 - val_mae: 0.6616 - val_mse: 0.8713 - lr: 0.0010
# Epoch 9/100
# 329/329 [==============================] - ETA: 0s - loss: 0.6326 - mae: 0.5572 - mse: 0.6326
# Epoch 00009: val_loss did not improve from 0.80969
# 329/329 [==============================] - 6s 19ms/step - loss: 0.6326 - mae: 0.5572 - mse: 0.6326 - val_loss: 0.8463 - val_mae: 0.6622 - val_mse: 0.8463 - lr: 0.0010
# Epoch 10/100
# 329/329 [==============================] - ETA: 0s - loss: 0.6163 - mae: 0.5521 - mse: 0.6163
# Epoch 00010: val_loss did not improve from 0.80969
# 329/329 [==============================] - 6s 19ms/step - loss: 0.6163 - mae: 0.5521 - mse: 0.6163 - val_loss: 0.8288 - val_mae: 0.6416 - val_mse: 0.8288 - lr: 0.0010
# Epoch 11/100
# 326/329 [============================>.] - ETA: 0s - loss: 0.6029 - mae: 0.5460 - mse: 0.6029
# Epoch 00011: val_loss did not improve from 0.80969
# 329/329 [==============================] - 6s 19ms/step - loss: 0.6029 - mae: 0.5459 - mse: 0.6029 - val_loss: 0.8501 - val_mae: 0.6672 - val_mse: 0.8501 - lr: 0.0010
# Epoch 12/100
# 328/329 [============================>.] - ETA: 0s - loss: 0.5945 - mae: 0.5417 - mse: 0.5945
# Epoch 00012: val_loss improved from 0.80969 to 0.80860, saving model to ./models/H18/best_ResNet50_tuning.hdf5
# 329/329 [==============================] - 8s 24ms/step - loss: 0.5946 - mae: 0.5417 - mse: 0.5946 - val_loss: 0.8086 - val_mae: 0.6663 - val_mse: 0.8086 - lr: 0.0010
# Epoch 13/100
# 329/329 [==============================] - ETA: 0s - loss: 0.5883 - mae: 0.5407 - mse: 0.5883
# Epoch 00013: val_loss did not improve from 0.80860
# 329/329 [==============================] - 6s 19ms/step - loss: 0.5883 - mae: 0.5407 - mse: 0.5883 - val_loss: 0.8549 - val_mae: 0.6589 - val_mse: 0.8549 - lr: 0.0010
# Epoch 14/100
# 327/329 [============================>.] - ETA: 0s - loss: 0.5827 - mae: 0.5365 - mse: 0.5827
# Epoch 00014: val_loss did not improve from 0.80860
# 329/329 [==============================] - 6s 19ms/step - loss: 0.5828 - mae: 0.5366 - mse: 0.5828 - val_loss: 0.8681 - val_mae: 0.6649 - val_mse: 0.8681 - lr: 0.0010
# Epoch 15/100
# 329/329 [==============================] - ETA: 0s - loss: 0.5667 - mae: 0.5313 - mse: 0.5667
# Epoch 00015: val_loss did not improve from 0.80860
# 329/329 [==============================] - 6s 19ms/step - loss: 0.5667 - mae: 0.5313 - mse: 0.5667 - val_loss: 0.8299 - val_mae: 0.6741 - val_mse: 0.8299 - lr: 0.0010
# Epoch 16/100
# 329/329 [==============================] - ETA: 0s - loss: 0.5627 - mae: 0.5295 - mse: 0.5627
# Epoch 00016: val_loss did not improve from 0.80860
# 329/329 [==============================] - 6s 19ms/step - loss: 0.5627 - mae: 0.5295 - mse: 0.5627 - val_loss: 0.8846 - val_mae: 0.6763 - val_mse: 0.8846 - lr: 0.0010
# Epoch 17/100
# 329/329 [==============================] - ETA: 0s - loss: 0.5493 - mae: 0.5219 - mse: 0.5493
# Epoch 00017: val_loss did not improve from 0.80860
# 329/329 [==============================] - 6s 19ms/step - loss: 0.5493 - mae: 0.5219 - mse: 0.5493 - val_loss: 0.8328 - val_mae: 0.6508 - val_mse: 0.8328 - lr: 0.0010
# Epoch 18/100
# 326/329 [============================>.] - ETA: 0s - loss: 0.5453 - mae: 0.5211 - mse: 0.5453
# Epoch 00018: val_loss did not improve from 0.80860
# 329/329 [==============================] - 6s 19ms/step - loss: 0.5446 - mae: 0.5208 - mse: 0.5446 - val_loss: 0.8787 - val_mae: 0.6491 - val_mse: 0.8787 - lr: 0.0010
# Epoch 19/100
# 329/329 [==============================] - ETA: 0s - loss: 0.5326 - mae: 0.5152 - mse: 0.5326
# Epoch 00019: val_loss did not improve from 0.80860
# 329/329 [==============================] - 6s 19ms/step - loss: 0.5326 - mae: 0.5152 - mse: 0.5326 - val_loss: 0.8566 - val_mae: 0.6680 - val_mse: 0.8566 - lr: 0.0010
# Epoch 20/100
# 329/329 [==============================] - ETA: 0s - loss: 0.5225 - mae: 0.5102 - mse: 0.5225
# Epoch 00020: val_loss did not improve from 0.80860
# 329/329 [==============================] - 6s 19ms/step - loss: 0.5225 - mae: 0.5102 - mse: 0.5225 - val_loss: 0.8927 - val_mae: 0.6813 - val_mse: 0.8927 - lr: 0.0010
# Epoch 21/100
# 326/329 [============================>.] - ETA: 0s - loss: 0.5207 - mae: 0.5101 - mse: 0.5207
# Epoch 00021: val_loss did not improve from 0.80860
# 329/329 [==============================] - 6s 19ms/step - loss: 0.5212 - mae: 0.5101 - mse: 0.5212 - val_loss: 0.8640 - val_mae: 0.6787 - val_mse: 0.8640 - lr: 0.0010
# Epoch 22/100
# 328/329 [============================>.] - ETA: 0s - loss: 0.5160 - mae: 0.5089 - mse: 0.5160
# Epoch 00022: val_loss did not improve from 0.80860
# 329/329 [==============================] - 6s 19ms/step - loss: 0.5162 - mae: 0.5089 - mse: 0.5162 - val_loss: 0.9101 - val_mae: 0.6607 - val_mse: 0.9101 - lr: 0.0010
# Epoch 23/100
# 327/329 [============================>.] - ETA: 0s - loss: 0.5020 - mae: 0.5020 - mse: 0.5020
# Epoch 00023: val_loss did not improve from 0.80860
# 329/329 [==============================] - 6s 19ms/step - loss: 0.5016 - mae: 0.5019 - mse: 0.5016 - val_loss: 0.8593 - val_mae: 0.6633 - val_mse: 0.8593 - lr: 0.0010
# Epoch 24/100
# 327/329 [============================>.] - ETA: 0s - loss: 0.4958 - mae: 0.4982 - mse: 0.4958
# Epoch 00024: val_loss did not improve from 0.80860
# 329/329 [==============================] - 6s 19ms/step - loss: 0.4961 - mae: 0.4983 - mse: 0.4961 - val_loss: 0.8708 - val_mae: 0.6670 - val_mse: 0.8708 - lr: 0.0010
# Epoch 25/100
# 327/329 [============================>.] - ETA: 0s - loss: 0.4858 - mae: 0.4952 - mse: 0.4858
# Epoch 00025: val_loss did not improve from 0.80860
# 329/329 [==============================] - 6s 19ms/step - loss: 0.4859 - mae: 0.4952 - mse: 0.4859 - val_loss: 0.8924 - val_mae: 0.6665 - val_mse: 0.8924 - lr: 0.0010
# Epoch 26/100
# 329/329 [==============================] - ETA: 0s - loss: 0.4763 - mae: 0.4918 - mse: 0.4763
# Epoch 00026: val_loss did not improve from 0.80860
# 329/329 [==============================] - 6s 19ms/step - loss: 0.4763 - mae: 0.4918 - mse: 0.4763 - val_loss: 0.9026 - val_mae: 0.6734 - val_mse: 0.9026 - lr: 0.0010
# Epoch 27/100
# 328/329 [============================>.] - ETA: 0s - loss: 0.4612 - mae: 0.4825 - mse: 0.4612
# Epoch 00027: val_loss did not improve from 0.80860
# 329/329 [==============================] - 6s 19ms/step - loss: 0.4610 - mae: 0.4825 - mse: 0.4610 - val_loss: 0.8847 - val_mae: 0.6669 - val_mse: 0.8847 - lr: 0.0010
# Epoch 28/100
# 329/329 [==============================] - ETA: 0s - loss: 0.4622 - mae: 0.4838 - mse: 0.4622
# Epoch 00028: val_loss did not improve from 0.80860
# 329/329 [==============================] - 6s 20ms/step - loss: 0.4622 - mae: 0.4838 - mse: 0.4622 - val_loss: 0.8670 - val_mae: 0.6615 - val_mse: 0.8670 - lr: 0.0010
# Epoch 29/100
# 326/329 [============================>.] - ETA: 0s - loss: 0.4530 - mae: 0.4806 - mse: 0.4530
# Epoch 00029: val_loss did not improve from 0.80860
# 329/329 [==============================] - 6s 19ms/step - loss: 0.4529 - mae: 0.4805 - mse: 0.4529 - val_loss: 0.8781 - val_mae: 0.6618 - val_mse: 0.8781 - lr: 0.0010
# Epoch 30/100
# 327/329 [============================>.] - ETA: 0s - loss: 0.4537 - mae: 0.4789 - mse: 0.4537
# Epoch 00030: val_loss did not improve from 0.80860
# 329/329 [==============================] - 6s 19ms/step - loss: 0.4538 - mae: 0.4789 - mse: 0.4538 - val_loss: 0.8887 - val_mae: 0.6816 - val_mse: 0.8887 - lr: 0.0010
# Epoch 31/100
# 329/329 [==============================] - ETA: 0s - loss: 0.4381 - mae: 0.4735 - mse: 0.4381
# Epoch 00031: val_loss did not improve from 0.80860
# 329/329 [==============================] - 6s 19ms/step - loss: 0.4381 - mae: 0.4735 - mse: 0.4381 - val_loss: 0.9073 - val_mae: 0.6859 - val_mse: 0.9073 - lr: 0.0010
# Epoch 32/100
# 327/329 [============================>.] - ETA: 0s - loss: 0.4292 - mae: 0.4683 - mse: 0.4292
# Epoch 00032: ReduceLROnPlateau reducing learning rate to 0.00020000000949949026.
#
# Epoch 00032: val_loss did not improve from 0.80860
# 329/329 [==============================] - 6s 19ms/step - loss: 0.4288 - mae: 0.4681 - mse: 0.4288 - val_loss: 0.8834 - val_mae: 0.6649 - val_mse: 0.8834 - lr: 0.0010
# Epoch 00032: early stopping
# 328/328 [==============================] - 3s 10ms/step
# MAE 0.6649, MSE 0.8834, RMSE 0.9399, MAPE 311.3744
