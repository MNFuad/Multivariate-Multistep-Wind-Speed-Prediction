# %%
from google.colab import drive
drive.mount('/content/drive/')
# %cd /content/drive/My\ Drive/Colab\ Notebooks\

# from tensorflow.keras.applications.vgg19 import VGG19
# from tensorflow.keras.applications.mobilenet_v2  import MobileNetV2
# from tensorflow.keras.applications.nasnet import NASNetLarge 
# from tensorflow.keras.applications.xception import Xception
# from tensorflow.keras.applications.resnet50 import ResNet50
# from tensorflow.keras.applications.resnet import ResNet101
# from tensorflow.keras.applications.resnet import ResNet152
from tensorflow.keras.applications.resnet_v2 import ResNet50V2
# from tensorflow.keras.applications.resnet_v2 import ResNet101V2
# from tensorflow.keras.applications.resnet_v2 import ResNet152V2
# from tensorflow.keras.applications.inceptionV3 import InceptionV3
# from tensorflow.keras.applications.resnet import InceptionResNetV2	
# from tensorflow.keras.applications.resnet import MobileNet
# from tensorflow.keras.applications.resnet import DenseNet121
# from tensorflow.keras.applications.resnet import DenseNet169
# from tensorflow.keras.applications.resnet import DenseNet201
# from tensorflow.keras.applications.resnet import NASNetMobile
# from tensorflow.keras.applications.resnet import NASNetLarge
# from tensorflow.keras.applications.resnet import EfficientNetB0
# from tensorflow.keras.applications.resnet import EfficientNetB1
# from tensorflow.keras.applications.resnet import EfficientNetB2
# from tensorflow.keras.applications.resnet import EfficientNetB3
# from tensorflow.keras.applications.resnet import EfficientNetB4
# from tensorflow.keras.applications.resnet import EfficientNetB5
# from tensorflow.keras.applications.resnet import EfficientNetB6
# from tensorflow.keras.applications.resnet import EfficientNetB7
from tensorflow.keras.layers import Input, Dropout
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Dense, GlobalAveragePooling2D
import numpy as np
from keras.utils import to_categorical
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint
from tensorflow.keras.callbacks import ReduceLROnPlateau
from tensorflow.keras.optimizers import Adam, RMSprop 
# !pip install keras-adamw
# from keras_adamw import AdamW
import os
from sklearn.utils import shuffle
from keras.utils import np_utils
import scipy.io as sio

# filename = 'NASNetLarge_tuning' 
# filename = 'Xception_tuning'
# filename = 'mobilenetV2_tuning'
# filename = 'ResNet50_tuning'
# filename = 'ResNet101_tuning'
filename = 'ResNet152_tuning'
filename = 'ResNet50V2_tuning'

#=============================================================================
print('Loading data...')
ExType = 'H1'
DataPath = './wind_data/Norm_Train_Val_data_Lag10_'+ExType+'.mat'   
train_data = sio.loadmat(DataPath)['XTrain']#[...,np.newaxis]
train_labels = sio.loadmat(DataPath)['YTrain']
train_labels = np.squeeze(train_labels)
valid_data = sio.loadmat(DataPath)['XVal']#[...,np.newaxis]
valid_labels = sio.loadmat(DataPath)['YVal']
valid_labels = np.squeeze(valid_labels)

print('Wind Train data dim.   (samples x lag x parameters)',train_data.shape)
print('Wind Train labels dim. (samples x lag x parameters)',train_labels.shape)
print('Wind Valid dim.        (samples x lag x parameters)',valid_data.shape)
print('Wind Valid labels dim. (samples x lag x parameters)',valid_labels.shape)

# data resizing
from tensorflow.keras.preprocessing.image import array_to_img
train_images = np.zeros((train_data.shape[0],32,32))
for i, im in enumerate(train_data):
  a = array_to_img(train_data[i,:, :, np.newaxis])
  train_images[i,...] = np.array(a.resize((32,32)))
valid_images = np.zeros((valid_data.shape[0],32,32))
for i, im in enumerate(valid_data):
  a = array_to_img(valid_data[i,:, :, np.newaxis])
  valid_images[i,...] = np.array(a.resize((32,32)))


# duplicate the data three times to look like rgb image
train_data = np.repeat(train_images[:, :, :, np.newaxis], 3, axis=3)
valid_data = np.repeat(valid_images[:, :, :, np.newaxis], 3, axis=3)
print('Wind Train images dim.   (samples x lag x parameters x channels)',train_data.shape)
#=============================================================================
    

base_model = ResNet50V2(weights='imagenet', include_top=False,
                      input_tensor=Input(shape=(train_data.shape[1],train_data.shape[2],3)))# new input shape 


noLayers = len(base_model.layers)
# add a global spatial average pooling layer
x = base_model.output
x = GlobalAveragePooling2D()(x)
# let's add a fully-connected layer
x = Dense(1024, activation='relu')(x)
x = Dropout(rate=0.2)(x)
x = Dense(512, activation='relu')(x)
x = Dropout(rate=0.2)(x)
# x = Dense(256, activation='relu')(x)
# and a logistic layer -- let's say we have 200 classes
predictions = Dense(1, activation='linear')(x)

# this is the model we will train
model = Model(inputs=base_model.input, outputs=predictions)

# first: train only the top layers (which were randomly initialized)
# i.e. freeze all convolutional InceptionV3 layers
# for layer in base_model.layers[:noLayers]:
#     layer.trainable = False

#second: fine tune all layers with small learning rate
# Unfreeze the base model
base_model.trainable = False
# print(model.summary())
# compile the model (should be done *after* setting layers to non-trainable)
optimizer = Adam(lr=1e-03, beta_1=0.9, beta_2=0.999, epsilon=1e-08, decay=1e-06, amsgrad=False)
# optimizer = RMSprop(learning_rate=0.001, rho=0.9, momentum=0.9, epsilon=1e-07)
# optimizer = AdamW(lr=1e-4, model=model)
model.compile(optimizer=optimizer, loss='mse',metrics=['mae','mse'])

saveTo = './models/'+ExType
if not os.path.exists(saveTo):
    os.makedirs(saveTo)
    
callbacks=[ReduceLROnPlateau(monitor='val_loss', factor=0.2, patience=20, 
            verbose=1, mode='auto', min_delta=0.0005, min_lr=1e-07),#0.0001
            EarlyStopping(monitor='val_loss', patience=20, verbose=1, mode='auto'),
            ModelCheckpoint(saveTo + '/best_'+filename+'.hdf5', monitor='val_loss', verbose=1, 
                            save_best_only=True, mode='auto')]

model.fit(train_data,train_labels,
          batch_size=128,
          epochs=100,
          shuffle=True,
          validation_data=(valid_data,valid_labels),
          verbose=1,
          callbacks=callbacks)
# Testing
# from sklearn.metrics import confusion_matrix
# import sklearn.metrics as skm
import matplotlib.pyplot as plt
from sklearn.metrics import mean_squared_error, mean_absolute_error
from math import sqrt

predictions = model.predict(valid_data,verbose=1)
# MAPE = np.mean(100*2.0 * np.abs(valid_labels - predictions) / (np.abs(valid_labels) + np.abs(predictions))).item()
MAPE = np.mean(np.abs((valid_labels - predictions) / valid_labels)) * 100
print("MAE {:.4}, MSE {:.4f}, RMSE {:.4f}, MAPE {:.4f}".format(
    mean_absolute_error(valid_labels, predictions),
    mean_squared_error(valid_labels, predictions),
    sqrt(mean_squared_error(valid_labels, predictions)),
    MAPE))
plt.scatter(valid_labels,predictions)
plt.figure(figsize=(30,6)); 
plt.plot(valid_labels, label='true')
plt.plot(predictions, label='pred')
plt.legend()
# Out:
# Drive already mounted at /content/drive/; to attempt to forcibly remount, call drive.mount("/content/drive/", force_remount=True).
# /content/drive/My Drive/Colab Notebooks
# Using TensorFlow backend.
# Loading data...
# Wind Train data dim.   (samples x lag x parameters) (42039, 10, 10)
# Wind Train labels dim. (samples x lag x parameters) (42039,)
# Wind Valid dim.        (samples x lag x parameters) (10502, 10, 10)
# Wind Valid labels dim. (samples x lag x parameters) (10502,)
# Wind Train images dim.   (samples x lag x parameters x channels) (42039, 32, 32, 3)
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/resnet/resnet50v2_weights_tf_dim_ordering_tf_kernels_notop.h5
# 94674944/94668760 [==============================] - 1s 0us/step
# Epoch 1/100
# 329/329 [==============================] - ETA: 0s - loss: 3939.6868 - mae: 12.7556 - mse: 3939.6868
# Epoch 00001: val_loss improved from inf to 0.94614, saving model to ./models/H1/best_ResNet50V2_tuning.hdf5
# 329/329 [==============================] - 8s 25ms/step - loss: 3939.6868 - mae: 12.7556 - mse: 3939.6868 - val_loss: 0.9461 - val_mae: 0.7370 - val_mse: 0.9461 - lr: 0.0010
# Epoch 2/100
# 328/329 [============================>.] - ETA: 0s - loss: 1.7714 - mae: 0.8199 - mse: 1.7714
# Epoch 00002: val_loss improved from 0.94614 to 0.89570, saving model to ./models/H1/best_ResNet50V2_tuning.hdf5
# 329/329 [==============================] - 7s 21ms/step - loss: 1.7700 - mae: 0.8196 - mse: 1.7700 - val_loss: 0.8957 - val_mae: 0.7070 - val_mse: 0.8957 - lr: 0.0010
# Epoch 3/100
# 326/329 [============================>.] - ETA: 0s - loss: 1.3584 - mae: 0.7446 - mse: 1.3584
# Epoch 00003: val_loss improved from 0.89570 to 0.86216, saving model to ./models/H1/best_ResNet50V2_tuning.hdf5
# 329/329 [==============================] - 7s 21ms/step - loss: 1.3562 - mae: 0.7443 - mse: 1.3562 - val_loss: 0.8622 - val_mae: 0.7005 - val_mse: 0.8622 - lr: 0.0010
# Epoch 4/100
# 327/329 [============================>.] - ETA: 0s - loss: 1.1251 - mae: 0.7038 - mse: 1.1251
# Epoch 00004: val_loss improved from 0.86216 to 0.85635, saving model to ./models/H1/best_ResNet50V2_tuning.hdf5
# 329/329 [==============================] - 7s 21ms/step - loss: 1.1248 - mae: 0.7038 - mse: 1.1248 - val_loss: 0.8563 - val_mae: 0.7002 - val_mse: 0.8563 - lr: 0.0010
# Epoch 5/100
# 328/329 [============================>.] - ETA: 0s - loss: 1.0435 - mae: 0.6876 - mse: 1.0435
# Epoch 00005: val_loss improved from 0.85635 to 0.83897, saving model to ./models/H1/best_ResNet50V2_tuning.hdf5
# 329/329 [==============================] - 7s 21ms/step - loss: 1.0430 - mae: 0.6875 - mse: 1.0430 - val_loss: 0.8390 - val_mae: 0.6846 - val_mse: 0.8390 - lr: 0.0010
# Epoch 6/100
# 328/329 [============================>.] - ETA: 0s - loss: 0.9551 - mae: 0.6598 - mse: 0.9551
# Epoch 00006: val_loss improved from 0.83897 to 0.75508, saving model to ./models/H1/best_ResNet50V2_tuning.hdf5
# 329/329 [==============================] - 7s 21ms/step - loss: 0.9562 - mae: 0.6601 - mse: 0.9562 - val_loss: 0.7551 - val_mae: 0.6544 - val_mse: 0.7551 - lr: 0.0010
# Epoch 7/100
# 327/329 [============================>.] - ETA: 0s - loss: 0.8102 - mae: 0.6204 - mse: 0.8102
# Epoch 00007: val_loss did not improve from 0.75508
# 329/329 [==============================] - 6s 19ms/step - loss: 0.8089 - mae: 0.6201 - mse: 0.8089 - val_loss: 0.7966 - val_mae: 0.6457 - val_mse: 0.7966 - lr: 0.0010
# Epoch 8/100
# 327/329 [============================>.] - ETA: 0s - loss: 0.7423 - mae: 0.5983 - mse: 0.7423
# Epoch 00008: val_loss did not improve from 0.75508
# 329/329 [==============================] - 6s 19ms/step - loss: 0.7420 - mae: 0.5981 - mse: 0.7420 - val_loss: 0.7668 - val_mae: 0.6535 - val_mse: 0.7668 - lr: 0.0010
# Epoch 9/100
# 328/329 [============================>.] - ETA: 0s - loss: 0.6922 - mae: 0.5808 - mse: 0.6922
# Epoch 00009: val_loss did not improve from 0.75508
# 329/329 [==============================] - 6s 19ms/step - loss: 0.6922 - mae: 0.5808 - mse: 0.6922 - val_loss: 0.7632 - val_mae: 0.6533 - val_mse: 0.7632 - lr: 0.0010
# Epoch 10/100
# 328/329 [============================>.] - ETA: 0s - loss: 0.6484 - mae: 0.5705 - mse: 0.6484
# Epoch 00010: val_loss improved from 0.75508 to 0.68029, saving model to ./models/H1/best_ResNet50V2_tuning.hdf5
# 329/329 [==============================] - 8s 24ms/step - loss: 0.6482 - mae: 0.5704 - mse: 0.6482 - val_loss: 0.6803 - val_mae: 0.6034 - val_mse: 0.6803 - lr: 0.0010
# Epoch 11/100
# 328/329 [============================>.] - ETA: 0s - loss: 0.6475 - mae: 0.5601 - mse: 0.6475
# Epoch 00011: val_loss did not improve from 0.68029
# 329/329 [==============================] - 6s 19ms/step - loss: 0.6476 - mae: 0.5601 - mse: 0.6476 - val_loss: 0.7553 - val_mae: 0.6526 - val_mse: 0.7553 - lr: 0.0010
# Epoch 12/100
# 326/329 [============================>.] - ETA: 0s - loss: 0.5999 - mae: 0.5500 - mse: 0.5999
# Epoch 00012: val_loss did not improve from 0.68029
# 329/329 [==============================] - 6s 19ms/step - loss: 0.5996 - mae: 0.5498 - mse: 0.5996 - val_loss: 0.7212 - val_mae: 0.6181 - val_mse: 0.7212 - lr: 0.0010
# Epoch 13/100
# 329/329 [==============================] - ETA: 0s - loss: 0.5856 - mae: 0.5414 - mse: 0.5856
# Epoch 00013: val_loss did not improve from 0.68029
# 329/329 [==============================] - 6s 19ms/step - loss: 0.5856 - mae: 0.5414 - mse: 0.5856 - val_loss: 0.6807 - val_mae: 0.6164 - val_mse: 0.6807 - lr: 0.0010
# Epoch 14/100
# 329/329 [==============================] - ETA: 0s - loss: 0.5617 - mae: 0.5360 - mse: 0.5617
# Epoch 00014: val_loss did not improve from 0.68029
# 329/329 [==============================] - 6s 19ms/step - loss: 0.5617 - mae: 0.5360 - mse: 0.5617 - val_loss: 0.7183 - val_mae: 0.6336 - val_mse: 0.7183 - lr: 0.0010
# Epoch 15/100
# 329/329 [==============================] - ETA: 0s - loss: 0.5381 - mae: 0.5277 - mse: 0.5381
# Epoch 00015: val_loss improved from 0.68029 to 0.65980, saving model to ./models/H1/best_ResNet50V2_tuning.hdf5
# 329/329 [==============================] - 8s 24ms/step - loss: 0.5381 - mae: 0.5277 - mse: 0.5381 - val_loss: 0.6598 - val_mae: 0.6057 - val_mse: 0.6598 - lr: 0.0010
# Epoch 16/100
# 329/329 [==============================] - ETA: 0s - loss: 0.5146 - mae: 0.5172 - mse: 0.5146
# Epoch 00016: val_loss improved from 0.65980 to 0.65652, saving model to ./models/H1/best_ResNet50V2_tuning.hdf5
# 329/329 [==============================] - 7s 21ms/step - loss: 0.5146 - mae: 0.5172 - mse: 0.5146 - val_loss: 0.6565 - val_mae: 0.6023 - val_mse: 0.6565 - lr: 0.0010
# Epoch 17/100
# 329/329 [==============================] - ETA: 0s - loss: 0.5100 - mae: 0.5143 - mse: 0.5100
# Epoch 00017: val_loss did not improve from 0.65652
# 329/329 [==============================] - 6s 19ms/step - loss: 0.5100 - mae: 0.5143 - mse: 0.5100 - val_loss: 0.6907 - val_mae: 0.6060 - val_mse: 0.6907 - lr: 0.0010
# Epoch 18/100
# 327/329 [============================>.] - ETA: 0s - loss: 0.5100 - mae: 0.5142 - mse: 0.5100
# Epoch 00018: val_loss improved from 0.65652 to 0.59417, saving model to ./models/H1/best_ResNet50V2_tuning.hdf5
# 329/329 [==============================] - 8s 23ms/step - loss: 0.5097 - mae: 0.5142 - mse: 0.5097 - val_loss: 0.5942 - val_mae: 0.5961 - val_mse: 0.5942 - lr: 0.0010
# Epoch 19/100
# 326/329 [============================>.] - ETA: 0s - loss: 0.4979 - mae: 0.5081 - mse: 0.4979
# Epoch 00019: val_loss did not improve from 0.59417
# 329/329 [==============================] - 6s 19ms/step - loss: 0.4977 - mae: 0.5081 - mse: 0.4977 - val_loss: 0.6734 - val_mae: 0.6043 - val_mse: 0.6734 - lr: 0.0010
# Epoch 20/100
# 327/329 [============================>.] - ETA: 0s - loss: 0.5043 - mae: 0.5089 - mse: 0.5043
# Epoch 00020: val_loss did not improve from 0.59417
# 329/329 [==============================] - 6s 19ms/step - loss: 0.5045 - mae: 0.5088 - mse: 0.5045 - val_loss: 0.6216 - val_mae: 0.5812 - val_mse: 0.6216 - lr: 0.0010
# Epoch 21/100
# 327/329 [============================>.] - ETA: 0s - loss: 0.4967 - mae: 0.5080 - mse: 0.4967
# Epoch 00021: val_loss did not improve from 0.59417
# 329/329 [==============================] - 6s 19ms/step - loss: 0.4972 - mae: 0.5083 - mse: 0.4972 - val_loss: 0.6388 - val_mae: 0.6041 - val_mse: 0.6388 - lr: 0.0010
# Epoch 22/100
# 327/329 [============================>.] - ETA: 0s - loss: 0.4916 - mae: 0.5038 - mse: 0.4916
# Epoch 00022: val_loss did not improve from 0.59417
# 329/329 [==============================] - 6s 19ms/step - loss: 0.4928 - mae: 0.5041 - mse: 0.4928 - val_loss: 0.7009 - val_mae: 0.6206 - val_mse: 0.7009 - lr: 0.0010
# Epoch 23/100
# 328/329 [============================>.] - ETA: 0s - loss: 0.4821 - mae: 0.5018 - mse: 0.4821
# Epoch 00023: val_loss did not improve from 0.59417
# 329/329 [==============================] - 6s 19ms/step - loss: 0.4820 - mae: 0.5018 - mse: 0.4820 - val_loss: 0.6631 - val_mae: 0.6012 - val_mse: 0.6631 - lr: 0.0010
# Epoch 24/100
# 329/329 [==============================] - ETA: 0s - loss: 0.4762 - mae: 0.4986 - mse: 0.4762
# Epoch 00024: val_loss did not improve from 0.59417
# 329/329 [==============================] - 6s 19ms/step - loss: 0.4762 - mae: 0.4986 - mse: 0.4762 - val_loss: 0.6546 - val_mae: 0.5996 - val_mse: 0.6546 - lr: 0.0010
# Epoch 25/100
# 329/329 [==============================] - ETA: 0s - loss: 0.4839 - mae: 0.5011 - mse: 0.4839
# Epoch 00025: val_loss improved from 0.59417 to 0.59276, saving model to ./models/H1/best_ResNet50V2_tuning.hdf5
# 329/329 [==============================] - 8s 24ms/step - loss: 0.4839 - mae: 0.5011 - mse: 0.4839 - val_loss: 0.5928 - val_mae: 0.5776 - val_mse: 0.5928 - lr: 0.0010
# Epoch 26/100
# 329/329 [==============================] - ETA: 0s - loss: 0.4747 - mae: 0.4968 - mse: 0.4747
# Epoch 00026: val_loss did not improve from 0.59276
# 329/329 [==============================] - 6s 19ms/step - loss: 0.4747 - mae: 0.4968 - mse: 0.4747 - val_loss: 0.6001 - val_mae: 0.5695 - val_mse: 0.6001 - lr: 0.0010
# Epoch 27/100
# 328/329 [============================>.] - ETA: 0s - loss: 0.4752 - mae: 0.4986 - mse: 0.4752
# Epoch 00027: val_loss did not improve from 0.59276
# 329/329 [==============================] - 6s 19ms/step - loss: 0.4753 - mae: 0.4987 - mse: 0.4753 - val_loss: 0.5968 - val_mae: 0.5623 - val_mse: 0.5968 - lr: 0.0010
# Epoch 28/100
# 328/329 [============================>.] - ETA: 0s - loss: 0.4726 - mae: 0.4966 - mse: 0.4726
# Epoch 00028: val_loss improved from 0.59276 to 0.58311, saving model to ./models/H1/best_ResNet50V2_tuning.hdf5
# 329/329 [==============================] - 7s 21ms/step - loss: 0.4726 - mae: 0.4966 - mse: 0.4726 - val_loss: 0.5831 - val_mae: 0.5681 - val_mse: 0.5831 - lr: 0.0010
# Epoch 29/100
# 326/329 [============================>.] - ETA: 0s - loss: 0.4669 - mae: 0.4933 - mse: 0.4669
# Epoch 00029: val_loss did not improve from 0.58311
# 329/329 [==============================] - 6s 19ms/step - loss: 0.4666 - mae: 0.4931 - mse: 0.4666 - val_loss: 0.6342 - val_mae: 0.5950 - val_mse: 0.6342 - lr: 0.0010
# Epoch 30/100
# 327/329 [============================>.] - ETA: 0s - loss: 0.4733 - mae: 0.4953 - mse: 0.4733
# Epoch 00030: val_loss did not improve from 0.58311
# 329/329 [==============================] - 6s 19ms/step - loss: 0.4732 - mae: 0.4952 - mse: 0.4732 - val_loss: 0.5979 - val_mae: 0.5637 - val_mse: 0.5979 - lr: 0.0010
# Epoch 31/100
# 328/329 [============================>.] - ETA: 0s - loss: 0.4659 - mae: 0.4930 - mse: 0.4659
# Epoch 00031: val_loss improved from 0.58311 to 0.56735, saving model to ./models/H1/best_ResNet50V2_tuning.hdf5
# 329/329 [==============================] - 7s 21ms/step - loss: 0.4661 - mae: 0.4931 - mse: 0.4661 - val_loss: 0.5673 - val_mae: 0.5518 - val_mse: 0.5673 - lr: 0.0010
# Epoch 32/100
# 329/329 [==============================] - ETA: 0s - loss: 0.4596 - mae: 0.4921 - mse: 0.4596
# Epoch 00032: val_loss improved from 0.56735 to 0.53964, saving model to ./models/H1/best_ResNet50V2_tuning.hdf5
# 329/329 [==============================] - 7s 21ms/step - loss: 0.4596 - mae: 0.4921 - mse: 0.4596 - val_loss: 0.5396 - val_mae: 0.5434 - val_mse: 0.5396 - lr: 0.0010
# Epoch 33/100
# 328/329 [============================>.] - ETA: 0s - loss: 0.4589 - mae: 0.4891 - mse: 0.4589
# Epoch 00033: val_loss did not improve from 0.53964
# 329/329 [==============================] - 6s 19ms/step - loss: 0.4589 - mae: 0.4891 - mse: 0.4589 - val_loss: 0.6463 - val_mae: 0.5790 - val_mse: 0.6463 - lr: 0.0010
# Epoch 34/100
# 329/329 [==============================] - ETA: 0s - loss: 0.4652 - mae: 0.4915 - mse: 0.4652
# Epoch 00034: val_loss did not improve from 0.53964
# 329/329 [==============================] - 6s 19ms/step - loss: 0.4652 - mae: 0.4915 - mse: 0.4652 - val_loss: 0.6798 - val_mae: 0.6239 - val_mse: 0.6798 - lr: 0.0010
# Epoch 35/100
# 328/329 [============================>.] - ETA: 0s - loss: 0.4631 - mae: 0.4904 - mse: 0.4631
# Epoch 00035: val_loss did not improve from 0.53964
# 329/329 [==============================] - 6s 19ms/step - loss: 0.4631 - mae: 0.4904 - mse: 0.4631 - val_loss: 0.5570 - val_mae: 0.5581 - val_mse: 0.5570 - lr: 0.0010
# Epoch 36/100
# 328/329 [============================>.] - ETA: 0s - loss: 0.4675 - mae: 0.4921 - mse: 0.4675
# Epoch 00036: val_loss did not improve from 0.53964
# 329/329 [==============================] - 6s 19ms/step - loss: 0.4672 - mae: 0.4920 - mse: 0.4672 - val_loss: 0.6612 - val_mae: 0.6161 - val_mse: 0.6612 - lr: 0.0010
# Epoch 37/100
# 328/329 [============================>.] - ETA: 0s - loss: 0.4550 - mae: 0.4870 - mse: 0.4550
# Epoch 00037: val_loss did not improve from 0.53964
# 329/329 [==============================] - 6s 19ms/step - loss: 0.4550 - mae: 0.4870 - mse: 0.4550 - val_loss: 0.6084 - val_mae: 0.6062 - val_mse: 0.6084 - lr: 0.0010
# Epoch 38/100
# 329/329 [==============================] - ETA: 0s - loss: 0.4607 - mae: 0.4858 - mse: 0.4607
# Epoch 00038: val_loss did not improve from 0.53964
# 329/329 [==============================] - 6s 19ms/step - loss: 0.4607 - mae: 0.4858 - mse: 0.4607 - val_loss: 0.6536 - val_mae: 0.6220 - val_mse: 0.6536 - lr: 0.0010
# Epoch 39/100
# 329/329 [==============================] - ETA: 0s - loss: 0.4681 - mae: 0.4907 - mse: 0.4681
# Epoch 00039: val_loss did not improve from 0.53964
# 329/329 [==============================] - 6s 19ms/step - loss: 0.4681 - mae: 0.4907 - mse: 0.4681 - val_loss: 0.5790 - val_mae: 0.5594 - val_mse: 0.5790 - lr: 0.0010
# Epoch 40/100
# 328/329 [============================>.] - ETA: 0s - loss: 0.4450 - mae: 0.4821 - mse: 0.4450
# Epoch 00040: val_loss did not improve from 0.53964
# 329/329 [==============================] - 6s 19ms/step - loss: 0.4451 - mae: 0.4822 - mse: 0.4451 - val_loss: 0.5523 - val_mae: 0.5419 - val_mse: 0.5523 - lr: 0.0010
# Epoch 41/100
# 329/329 [==============================] - ETA: 0s - loss: 0.4514 - mae: 0.4839 - mse: 0.4514
# Epoch 00041: val_loss did not improve from 0.53964
# 329/329 [==============================] - 6s 19ms/step - loss: 0.4514 - mae: 0.4839 - mse: 0.4514 - val_loss: 0.5792 - val_mae: 0.5691 - val_mse: 0.5792 - lr: 0.0010
# Epoch 42/100
# 329/329 [==============================] - ETA: 0s - loss: 0.4432 - mae: 0.4807 - mse: 0.4432
# Epoch 00042: val_loss did not improve from 0.53964
# 329/329 [==============================] - 6s 19ms/step - loss: 0.4432 - mae: 0.4807 - mse: 0.4432 - val_loss: 0.5512 - val_mae: 0.5647 - val_mse: 0.5512 - lr: 0.0010
# Epoch 43/100
# 328/329 [============================>.] - ETA: 0s - loss: 0.4469 - mae: 0.4828 - mse: 0.4469
# Epoch 00043: val_loss improved from 0.53964 to 0.51664, saving model to ./models/H1/best_ResNet50V2_tuning.hdf5
# 329/329 [==============================] - 8s 24ms/step - loss: 0.4470 - mae: 0.4828 - mse: 0.4470 - val_loss: 0.5166 - val_mae: 0.5344 - val_mse: 0.5166 - lr: 0.0010
# Epoch 44/100
# 329/329 [==============================] - ETA: 0s - loss: 0.4482 - mae: 0.4822 - mse: 0.4482
# Epoch 00044: val_loss improved from 0.51664 to 0.50730, saving model to ./models/H1/best_ResNet50V2_tuning.hdf5
# 329/329 [==============================] - 7s 21ms/step - loss: 0.4482 - mae: 0.4822 - mse: 0.4482 - val_loss: 0.5073 - val_mae: 0.5457 - val_mse: 0.5073 - lr: 0.0010
# Epoch 45/100
# 328/329 [============================>.] - ETA: 0s - loss: 0.4392 - mae: 0.4785 - mse: 0.4392
# Epoch 00045: val_loss did not improve from 0.50730
# 329/329 [==============================] - 6s 19ms/step - loss: 0.4394 - mae: 0.4786 - mse: 0.4394 - val_loss: 0.5913 - val_mae: 0.5708 - val_mse: 0.5913 - lr: 0.0010
# Epoch 46/100
# 329/329 [==============================] - ETA: 0s - loss: 0.4400 - mae: 0.4784 - mse: 0.4400
# Epoch 00046: val_loss did not improve from 0.50730
# 329/329 [==============================] - 6s 19ms/step - loss: 0.4400 - mae: 0.4784 - mse: 0.4400 - val_loss: 0.5737 - val_mae: 0.5677 - val_mse: 0.5737 - lr: 0.0010
# Epoch 47/100
# 329/329 [==============================] - ETA: 0s - loss: 0.4433 - mae: 0.4788 - mse: 0.4433
# Epoch 00047: val_loss did not improve from 0.50730
# 329/329 [==============================] - 6s 19ms/step - loss: 0.4433 - mae: 0.4788 - mse: 0.4433 - val_loss: 0.5684 - val_mae: 0.5746 - val_mse: 0.5684 - lr: 0.0010
# Epoch 48/100
# 329/329 [==============================] - ETA: 0s - loss: 0.4429 - mae: 0.4786 - mse: 0.4429
# Epoch 00048: val_loss did not improve from 0.50730
# 329/329 [==============================] - 6s 19ms/step - loss: 0.4429 - mae: 0.4786 - mse: 0.4429 - val_loss: 0.5903 - val_mae: 0.5840 - val_mse: 0.5903 - lr: 0.0010
# Epoch 49/100
# 327/329 [============================>.] - ETA: 0s - loss: 0.4357 - mae: 0.4766 - mse: 0.4357
# Epoch 00049: val_loss improved from 0.50730 to 0.50636, saving model to ./models/H1/best_ResNet50V2_tuning.hdf5
# 329/329 [==============================] - 8s 23ms/step - loss: 0.4357 - mae: 0.4765 - mse: 0.4357 - val_loss: 0.5064 - val_mae: 0.5397 - val_mse: 0.5064 - lr: 0.0010
# Epoch 50/100
# 327/329 [============================>.] - ETA: 0s - loss: 0.4350 - mae: 0.4758 - mse: 0.4350
# Epoch 00050: val_loss did not improve from 0.50636
# 329/329 [==============================] - 6s 19ms/step - loss: 0.4349 - mae: 0.4757 - mse: 0.4349 - val_loss: 0.5796 - val_mae: 0.6025 - val_mse: 0.5796 - lr: 0.0010
# Epoch 51/100
# 326/329 [============================>.] - ETA: 0s - loss: 0.4310 - mae: 0.4756 - mse: 0.4310
# Epoch 00051: val_loss did not improve from 0.50636
# 329/329 [==============================] - 6s 19ms/step - loss: 0.4315 - mae: 0.4759 - mse: 0.4315 - val_loss: 0.5418 - val_mae: 0.5607 - val_mse: 0.5418 - lr: 0.0010
# Epoch 52/100
# 329/329 [==============================] - ETA: 0s - loss: 0.4350 - mae: 0.4767 - mse: 0.4350
# Epoch 00052: val_loss did not improve from 0.50636
# 329/329 [==============================] - 6s 19ms/step - loss: 0.4350 - mae: 0.4767 - mse: 0.4350 - val_loss: 0.5316 - val_mae: 0.5447 - val_mse: 0.5316 - lr: 0.0010
# Epoch 53/100
# 328/329 [============================>.] - ETA: 0s - loss: 0.4412 - mae: 0.4781 - mse: 0.4412
# Epoch 00053: val_loss did not improve from 0.50636
# 329/329 [==============================] - 6s 19ms/step - loss: 0.4413 - mae: 0.4781 - mse: 0.4413 - val_loss: 0.5125 - val_mae: 0.5395 - val_mse: 0.5125 - lr: 0.0010
# Epoch 54/100
# 329/329 [==============================] - ETA: 0s - loss: 0.4294 - mae: 0.4724 - mse: 0.4294
# Epoch 00054: val_loss did not improve from 0.50636
# 329/329 [==============================] - 6s 18ms/step - loss: 0.4294 - mae: 0.4724 - mse: 0.4294 - val_loss: 0.5490 - val_mae: 0.5708 - val_mse: 0.5490 - lr: 0.0010
# Epoch 55/100
# 329/329 [==============================] - ETA: 0s - loss: 0.4464 - mae: 0.4800 - mse: 0.4464
# Epoch 00055: val_loss did not improve from 0.50636
# 329/329 [==============================] - 6s 19ms/step - loss: 0.4464 - mae: 0.4800 - mse: 0.4464 - val_loss: 0.5649 - val_mae: 0.5690 - val_mse: 0.5649 - lr: 0.0010
# Epoch 56/100
# 328/329 [============================>.] - ETA: 0s - loss: 0.4279 - mae: 0.4726 - mse: 0.4279
# Epoch 00056: val_loss did not improve from 0.50636
# 329/329 [==============================] - 6s 19ms/step - loss: 0.4277 - mae: 0.4725 - mse: 0.4277 - val_loss: 0.5610 - val_mae: 0.5634 - val_mse: 0.5610 - lr: 0.0010
# Epoch 57/100
# 329/329 [==============================] - ETA: 0s - loss: 0.4472 - mae: 0.4791 - mse: 0.4472
# Epoch 00057: val_loss did not improve from 0.50636
# 329/329 [==============================] - 6s 19ms/step - loss: 0.4472 - mae: 0.4791 - mse: 0.4472 - val_loss: 0.5745 - val_mae: 0.5618 - val_mse: 0.5745 - lr: 0.0010
# Epoch 58/100
# 329/329 [==============================] - ETA: 0s - loss: 0.4320 - mae: 0.4717 - mse: 0.4320
# Epoch 00058: val_loss improved from 0.50636 to 0.49079, saving model to ./models/H1/best_ResNet50V2_tuning.hdf5
# 329/329 [==============================] - 8s 24ms/step - loss: 0.4320 - mae: 0.4717 - mse: 0.4320 - val_loss: 0.4908 - val_mae: 0.5219 - val_mse: 0.4908 - lr: 0.0010
# Epoch 59/100
# 328/329 [============================>.] - ETA: 0s - loss: 0.4459 - mae: 0.4821 - mse: 0.4459
# Epoch 00059: val_loss did not improve from 0.49079
# 329/329 [==============================] - 6s 19ms/step - loss: 0.4460 - mae: 0.4821 - mse: 0.4460 - val_loss: 0.5402 - val_mae: 0.5460 - val_mse: 0.5402 - lr: 0.0010
# Epoch 60/100
# 328/329 [============================>.] - ETA: 0s - loss: 0.4356 - mae: 0.4763 - mse: 0.4356
# Epoch 00060: val_loss did not improve from 0.49079
# 329/329 [==============================] - 6s 19ms/step - loss: 0.4354 - mae: 0.4762 - mse: 0.4354 - val_loss: 0.5537 - val_mae: 0.5563 - val_mse: 0.5537 - lr: 0.0010
# Epoch 61/100
# 329/329 [==============================] - ETA: 0s - loss: 0.4432 - mae: 0.4748 - mse: 0.4432
# Epoch 00061: val_loss did not improve from 0.49079
# 329/329 [==============================] - 6s 19ms/step - loss: 0.4432 - mae: 0.4748 - mse: 0.4432 - val_loss: 0.5549 - val_mae: 0.5733 - val_mse: 0.5549 - lr: 0.0010
# Epoch 62/100
# 329/329 [==============================] - ETA: 0s - loss: 0.4380 - mae: 0.4776 - mse: 0.4380
# Epoch 00062: val_loss did not improve from 0.49079
# 329/329 [==============================] - 6s 19ms/step - loss: 0.4380 - mae: 0.4776 - mse: 0.4380 - val_loss: 0.5257 - val_mae: 0.5652 - val_mse: 0.5257 - lr: 0.0010
# Epoch 63/100
# 328/329 [============================>.] - ETA: 0s - loss: 0.4278 - mae: 0.4725 - mse: 0.4278
# Epoch 00063: val_loss did not improve from 0.49079
# 329/329 [==============================] - 6s 18ms/step - loss: 0.4276 - mae: 0.4724 - mse: 0.4276 - val_loss: 0.5069 - val_mae: 0.5284 - val_mse: 0.5069 - lr: 0.0010
# Epoch 64/100
# 328/329 [============================>.] - ETA: 0s - loss: 0.4308 - mae: 0.4723 - mse: 0.4308
# Epoch 00064: val_loss did not improve from 0.49079
# 329/329 [==============================] - 6s 19ms/step - loss: 0.4306 - mae: 0.4722 - mse: 0.4306 - val_loss: 0.4919 - val_mae: 0.5224 - val_mse: 0.4919 - lr: 0.0010
# Epoch 65/100
# 329/329 [==============================] - ETA: 0s - loss: 0.4413 - mae: 0.4784 - mse: 0.4413
# Epoch 00065: val_loss did not improve from 0.49079
# 329/329 [==============================] - 6s 19ms/step - loss: 0.4413 - mae: 0.4784 - mse: 0.4413 - val_loss: 0.5942 - val_mae: 0.5994 - val_mse: 0.5942 - lr: 0.0010
# Epoch 66/100
# 328/329 [============================>.] - ETA: 0s - loss: 0.4426 - mae: 0.4799 - mse: 0.4426
# Epoch 00066: val_loss did not improve from 0.49079
# 329/329 [==============================] - 6s 18ms/step - loss: 0.4424 - mae: 0.4798 - mse: 0.4424 - val_loss: 0.5690 - val_mae: 0.5823 - val_mse: 0.5690 - lr: 0.0010
# Epoch 67/100
# 327/329 [============================>.] - ETA: 0s - loss: 0.4319 - mae: 0.4733 - mse: 0.4319
# Epoch 00067: val_loss did not improve from 0.49079
# 329/329 [==============================] - 6s 18ms/step - loss: 0.4319 - mae: 0.4733 - mse: 0.4319 - val_loss: 0.4945 - val_mae: 0.5222 - val_mse: 0.4945 - lr: 0.0010
# Epoch 68/100
# 329/329 [==============================] - ETA: 0s - loss: 0.4279 - mae: 0.4720 - mse: 0.4279
# Epoch 00068: val_loss did not improve from 0.49079
# 329/329 [==============================] - 6s 18ms/step - loss: 0.4279 - mae: 0.4720 - mse: 0.4279 - val_loss: 0.5254 - val_mae: 0.5323 - val_mse: 0.5254 - lr: 0.0010
# Epoch 69/100
# 329/329 [==============================] - ETA: 0s - loss: 0.4269 - mae: 0.4709 - mse: 0.4269
# Epoch 00069: val_loss did not improve from 0.49079
# 329/329 [==============================] - 6s 18ms/step - loss: 0.4269 - mae: 0.4709 - mse: 0.4269 - val_loss: 0.5623 - val_mae: 0.5630 - val_mse: 0.5623 - lr: 0.0010
# Epoch 70/100
# 329/329 [==============================] - ETA: 0s - loss: 0.4318 - mae: 0.4729 - mse: 0.4318
# Epoch 00070: val_loss did not improve from 0.49079
# 329/329 [==============================] - 6s 18ms/step - loss: 0.4318 - mae: 0.4729 - mse: 0.4318 - val_loss: 0.5187 - val_mae: 0.5268 - val_mse: 0.5187 - lr: 0.0010
# Epoch 71/100
# 329/329 [==============================] - ETA: 0s - loss: 0.4169 - mae: 0.4683 - mse: 0.4169
# Epoch 00071: val_loss did not improve from 0.49079
# 329/329 [==============================] - 6s 18ms/step - loss: 0.4169 - mae: 0.4683 - mse: 0.4169 - val_loss: 0.5115 - val_mae: 0.5176 - val_mse: 0.5115 - lr: 0.0010
# Epoch 72/100
# 329/329 [==============================] - ETA: 0s - loss: 0.4185 - mae: 0.4652 - mse: 0.4185
# Epoch 00072: val_loss did not improve from 0.49079
# 329/329 [==============================] - 6s 19ms/step - loss: 0.4185 - mae: 0.4652 - mse: 0.4185 - val_loss: 0.5024 - val_mae: 0.5338 - val_mse: 0.5024 - lr: 0.0010
# Epoch 73/100
# 329/329 [==============================] - ETA: 0s - loss: 0.4255 - mae: 0.4695 - mse: 0.4255
# Epoch 00073: val_loss did not improve from 0.49079
# 329/329 [==============================] - 6s 18ms/step - loss: 0.4255 - mae: 0.4695 - mse: 0.4255 - val_loss: 0.5348 - val_mae: 0.5365 - val_mse: 0.5348 - lr: 0.0010
# Epoch 74/100
# 329/329 [==============================] - ETA: 0s - loss: 0.4162 - mae: 0.4677 - mse: 0.4162
# Epoch 00074: val_loss did not improve from 0.49079
# 329/329 [==============================] - 6s 19ms/step - loss: 0.4162 - mae: 0.4677 - mse: 0.4162 - val_loss: 0.5031 - val_mae: 0.5225 - val_mse: 0.5031 - lr: 0.0010
# Epoch 75/100
# 329/329 [==============================] - ETA: 0s - loss: 0.4230 - mae: 0.4687 - mse: 0.4230
# Epoch 00075: val_loss did not improve from 0.49079
# 329/329 [==============================] - 6s 19ms/step - loss: 0.4230 - mae: 0.4687 - mse: 0.4230 - val_loss: 0.5242 - val_mae: 0.5401 - val_mse: 0.5242 - lr: 0.0010
# Epoch 76/100
# 329/329 [==============================] - ETA: 0s - loss: 0.4203 - mae: 0.4684 - mse: 0.4203
# Epoch 00076: val_loss did not improve from 0.49079
# 329/329 [==============================] - 6s 18ms/step - loss: 0.4203 - mae: 0.4684 - mse: 0.4203 - val_loss: 0.5076 - val_mae: 0.5424 - val_mse: 0.5076 - lr: 0.0010
# Epoch 77/100
# 327/329 [============================>.] - ETA: 0s - loss: 0.4110 - mae: 0.4631 - mse: 0.4110
# Epoch 00077: val_loss did not improve from 0.49079
# 329/329 [==============================] - 6s 19ms/step - loss: 0.4108 - mae: 0.4630 - mse: 0.4108 - val_loss: 0.5014 - val_mae: 0.5375 - val_mse: 0.5014 - lr: 0.0010
# Epoch 78/100
# 329/329 [==============================] - ETA: 0s - loss: 0.4290 - mae: 0.4701 - mse: 0.4290
# Epoch 00078: ReduceLROnPlateau reducing learning rate to 0.00020000000949949026.
#
# Epoch 00078: val_loss did not improve from 0.49079
# 329/329 [==============================] - 6s 19ms/step - loss: 0.4290 - mae: 0.4701 - mse: 0.4290 - val_loss: 0.5575 - val_mae: 0.5535 - val_mse: 0.5575 - lr: 0.0010
# Epoch 00078: early stopping
# 329/329 [==============================] - 3s 9ms/step
# MAE 0.5535, MSE 0.5575, RMSE 0.7467, MAPE 257.0916
