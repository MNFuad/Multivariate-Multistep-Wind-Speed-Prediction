# %%
from google.colab import drive
drive.mount('/content/drive/')
# %cd /content/drive/My\ Drive/Colab\ Notebooks\

# from tensorflow.keras.applications.mobilenet_v2  import MobileNetV2
# from tensorflow.keras.applications.nasnet import NASNetLarge 
# from tensorflow.keras.applications.xception import Xception
from tensorflow.keras.applications.vgg19 import VGG19
from tensorflow.keras.layers import Input, Dropout
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Dense, GlobalAveragePooling2D
import numpy as np
from keras.utils import to_categorical
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint
from tensorflow.keras.callbacks import ReduceLROnPlateau
from tensorflow.keras.optimizers import Adam, RMSprop 
# !pip install keras-adamw
# from keras_adamw import AdamW
import os
from sklearn.utils import shuffle
from keras.utils import np_utils
import scipy.io as sio

# filename = 'NASNetLarge_tuning' 
# filename = 'Xception_tuning'
filename = 'vgg19_tuning'

#=============================================================================
print('Loading data...')
ExType = 'H18'
DataPath = './wind_data/Norm_Train_Val_data_Lag10_'+ExType+'.mat'   
train_data = sio.loadmat(DataPath)['XTrain']#[...,np.newaxis]
train_labels = sio.loadmat(DataPath)['YTrain']
train_labels = np.squeeze(train_labels)
valid_data = sio.loadmat(DataPath)['XVal']#[...,np.newaxis]
valid_labels = sio.loadmat(DataPath)['YVal']
valid_labels = np.squeeze(valid_labels)

print('Wind Train data dim.   (samples x lag x parameters)',train_data.shape)
print('Wind Train labels dim. (samples x lag x parameters)',train_labels.shape)
print('Wind Valid dim.        (samples x lag x parameters)',valid_data.shape)
print('Wind Valid labels dim. (samples x lag x parameters)',valid_labels.shape)

# data resizing
from tensorflow.keras.preprocessing.image import array_to_img
train_images = np.zeros((train_data.shape[0],32,32))
for i, im in enumerate(train_data):
  a = array_to_img(train_data[i,:, :, np.newaxis])
  train_images[i,...] = np.array(a.resize((32,32)))
valid_images = np.zeros((valid_data.shape[0],32,32))
for i, im in enumerate(valid_data):
  a = array_to_img(valid_data[i,:, :, np.newaxis])
  valid_images[i,...] = np.array(a.resize((32,32)))


# duplicate the data three times to look like rgb image
train_data = np.repeat(train_images[:, :, :, np.newaxis], 3, axis=3)
valid_data = np.repeat(valid_images[:, :, :, np.newaxis], 3, axis=3)
print('Wind Train images dim.   (samples x lag x parameters x channels)',train_data.shape)
#=============================================================================
    

base_model = VGG19(weights='imagenet', include_top=False,
                      input_tensor=Input(shape=(train_data.shape[1],train_data.shape[2],3)))# new input shape 


noLayers = len(base_model.layers)
# add a global spatial average pooling layer
x = base_model.output
x = GlobalAveragePooling2D()(x)
# let's add a fully-connected layer
x = Dense(1024, activation='relu')(x)
x = Dropout(rate=0.2)(x)
x = Dense(512, activation='relu')(x)
x = Dropout(rate=0.2)(x)
# x = Dense(256, activation='relu')(x)
# and a logistic layer -- let's say we have 200 classes
predictions = Dense(1, activation='linear')(x)

# this is the model we will train
model = Model(inputs=base_model.input, outputs=predictions)

# first: train only the top layers (which were randomly initialized)
# i.e. freeze all convolutional InceptionV3 layers
# for layer in base_model.layers[:noLayers]:
#     layer.trainable = False

#second: fine tune all layers with small learning rate
# Unfreeze the base model
base_model.trainable = False
# print(model.summary())
# compile the model (should be done *after* setting layers to non-trainable)
optimizer = Adam(lr=1e-03, beta_1=0.9, beta_2=0.999, epsilon=1e-08, decay=1e-06, amsgrad=False)
# optimizer = RMSprop(learning_rate=0.001, rho=0.9, momentum=0.9, epsilon=1e-07)
# optimizer = AdamW(lr=1e-4, model=model)
model.compile(optimizer=optimizer, loss='mse',metrics=['mae','mse'])

saveTo = './models/'+ExType
if not os.path.exists(saveTo):
    os.makedirs(saveTo)
    
callbacks=[ReduceLROnPlateau(monitor='val_loss', factor=0.2, patience=10, 
            verbose=1, mode='auto', min_delta=0.0005, min_lr=1e-07),#0.0001
            EarlyStopping(monitor='val_loss', patience=15, verbose=1, mode='auto'),
            ModelCheckpoint(saveTo + '/best_'+filename+'.hdf5', monitor='val_loss', verbose=1, 
                            save_best_only=True, mode='auto')]

model.fit(train_data,train_labels,
          batch_size=128,
          epochs=100,
          shuffle=True,
          validation_data=(valid_data,valid_labels),
          verbose=1,
          callbacks=callbacks)
# Testing
# from sklearn.metrics import confusion_matrix
# import sklearn.metrics as skm
import matplotlib.pyplot as plt
from sklearn.metrics import mean_squared_error, mean_absolute_error
from math import sqrt

predictions = model.predict(valid_data,verbose=1)
# MAPE = np.mean(100*2.0 * np.abs(valid_labels - predictions) / (np.abs(valid_labels) + np.abs(predictions))).item()
MAPE = np.mean(np.abs((valid_labels - predictions) / valid_labels)) * 100
print("MAE {:.4}, MSE {:.4f}, RMSE {:.4f}, MAPE {:.4f}".format(
    mean_absolute_error(valid_labels, predictions),
    mean_squared_error(valid_labels, predictions),
    sqrt(mean_squared_error(valid_labels, predictions)),
    MAPE))
plt.scatter(valid_labels,predictions)
plt.figure(figsize=(30,6)); 
plt.plot(valid_labels, label='true')
plt.plot(predictions, label='pred')
plt.legend()
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive/
# /content/drive/My Drive/Colab Notebooks
# Using TensorFlow backend.
# Loading data...
# Wind Train data dim.   (samples x lag x parameters) (42022, 10, 10)
# Wind Train labels dim. (samples x lag x parameters) (42022,)
# Wind Valid dim.        (samples x lag x parameters) (10485, 10, 10)
# Wind Valid labels dim. (samples x lag x parameters) (10485,)
# Wind Train images dim.   (samples x lag x parameters x channels) (42022, 32, 32, 3)
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/vgg19/vgg19_weights_tf_dim_ordering_tf_kernels_notop.h5
# 80142336/80134624 [==============================] - 2s 0us/step
# Epoch 1/100
# 329/329 [==============================] - ETA: 0s - loss: 95.5263 - mae: 2.7676 - mse: 95.5263
# Epoch 00001: val_loss improved from inf to 0.96559, saving model to ./models/H18/best_vgg19_tuning.hdf5
# 329/329 [==============================] - 7s 20ms/step - loss: 95.5263 - mae: 2.7676 - mse: 95.5263 - val_loss: 0.9656 - val_mae: 0.7526 - val_mse: 0.9656 - lr: 0.0010
# Epoch 2/100
# 329/329 [==============================] - ETA: 0s - loss: 0.9118 - mae: 0.6674 - mse: 0.9118
# Epoch 00002: val_loss improved from 0.96559 to 0.90730, saving model to ./models/H18/best_vgg19_tuning.hdf5
# 329/329 [==============================] - 6s 18ms/step - loss: 0.9118 - mae: 0.6674 - mse: 0.9118 - val_loss: 0.9073 - val_mae: 0.7263 - val_mse: 0.9073 - lr: 0.0010
# Epoch 3/100
# 329/329 [==============================] - ETA: 0s - loss: 0.8332 - mae: 0.6394 - mse: 0.8332
# Epoch 00003: val_loss improved from 0.90730 to 0.90324, saving model to ./models/H18/best_vgg19_tuning.hdf5
# 329/329 [==============================] - 6s 18ms/step - loss: 0.8332 - mae: 0.6394 - mse: 0.8332 - val_loss: 0.9032 - val_mae: 0.7242 - val_mse: 0.9032 - lr: 0.0010
# Epoch 4/100
# 329/329 [==============================] - ETA: 0s - loss: 0.8051 - mae: 0.6266 - mse: 0.8051
# Epoch 00004: val_loss improved from 0.90324 to 0.88774, saving model to ./models/H18/best_vgg19_tuning.hdf5
# 329/329 [==============================] - 6s 18ms/step - loss: 0.8051 - mae: 0.6266 - mse: 0.8051 - val_loss: 0.8877 - val_mae: 0.7086 - val_mse: 0.8877 - lr: 0.0010
# Epoch 5/100
# 329/329 [==============================] - ETA: 0s - loss: 0.7783 - mae: 0.6185 - mse: 0.7783
# Epoch 00005: val_loss improved from 0.88774 to 0.87923, saving model to ./models/H18/best_vgg19_tuning.hdf5
# 329/329 [==============================] - 6s 18ms/step - loss: 0.7783 - mae: 0.6185 - mse: 0.7783 - val_loss: 0.8792 - val_mae: 0.6952 - val_mse: 0.8792 - lr: 0.0010
# Epoch 6/100
# 329/329 [==============================] - ETA: 0s - loss: 0.7596 - mae: 0.6092 - mse: 0.7596
# Epoch 00006: val_loss did not improve from 0.87923
# 329/329 [==============================] - 6s 18ms/step - loss: 0.7596 - mae: 0.6092 - mse: 0.7596 - val_loss: 0.8794 - val_mae: 0.6775 - val_mse: 0.8794 - lr: 0.0010
# Epoch 7/100
# 329/329 [==============================] - ETA: 0s - loss: 0.7459 - mae: 0.6037 - mse: 0.7459
# Epoch 00007: val_loss improved from 0.87923 to 0.87495, saving model to ./models/H18/best_vgg19_tuning.hdf5
# 329/329 [==============================] - 7s 21ms/step - loss: 0.7459 - mae: 0.6037 - mse: 0.7459 - val_loss: 0.8750 - val_mae: 0.6841 - val_mse: 0.8750 - lr: 0.0010
# Epoch 8/100
# 329/329 [==============================] - ETA: 0s - loss: 0.7305 - mae: 0.5976 - mse: 0.7305
# Epoch 00008: val_loss improved from 0.87495 to 0.85989, saving model to ./models/H18/best_vgg19_tuning.hdf5
# 329/329 [==============================] - 6s 19ms/step - loss: 0.7305 - mae: 0.5976 - mse: 0.7305 - val_loss: 0.8599 - val_mae: 0.6827 - val_mse: 0.8599 - lr: 0.0010
# Epoch 9/100
# 329/329 [==============================] - ETA: 0s - loss: 0.7191 - mae: 0.5944 - mse: 0.7191
# Epoch 00009: val_loss did not improve from 0.85989
# 329/329 [==============================] - 6s 18ms/step - loss: 0.7191 - mae: 0.5944 - mse: 0.7191 - val_loss: 0.8661 - val_mae: 0.6801 - val_mse: 0.8661 - lr: 0.0010
# Epoch 10/100
# 329/329 [==============================] - ETA: 0s - loss: 0.7039 - mae: 0.5885 - mse: 0.7039
# Epoch 00010: val_loss improved from 0.85989 to 0.85739, saving model to ./models/H18/best_vgg19_tuning.hdf5
# 329/329 [==============================] - 7s 21ms/step - loss: 0.7039 - mae: 0.5885 - mse: 0.7039 - val_loss: 0.8574 - val_mae: 0.6829 - val_mse: 0.8574 - lr: 0.0010
# Epoch 11/100
# 329/329 [==============================] - ETA: 0s - loss: 0.7048 - mae: 0.5867 - mse: 0.7048
# Epoch 00011: val_loss did not improve from 0.85739
# 329/329 [==============================] - 6s 17ms/step - loss: 0.7048 - mae: 0.5867 - mse: 0.7048 - val_loss: 0.8870 - val_mae: 0.6731 - val_mse: 0.8870 - lr: 0.0010
# Epoch 12/100
# 329/329 [==============================] - ETA: 0s - loss: 0.6972 - mae: 0.5850 - mse: 0.6972
# Epoch 00012: val_loss did not improve from 0.85739
# 329/329 [==============================] - 6s 17ms/step - loss: 0.6972 - mae: 0.5850 - mse: 0.6972 - val_loss: 0.8671 - val_mae: 0.6776 - val_mse: 0.8671 - lr: 0.0010
# Epoch 13/100
# 329/329 [==============================] - ETA: 0s - loss: 0.6860 - mae: 0.5811 - mse: 0.6860
# Epoch 00013: val_loss improved from 0.85739 to 0.84776, saving model to ./models/H18/best_vgg19_tuning.hdf5
# 329/329 [==============================] - 7s 20ms/step - loss: 0.6860 - mae: 0.5811 - mse: 0.6860 - val_loss: 0.8478 - val_mae: 0.6722 - val_mse: 0.8478 - lr: 0.0010
# Epoch 14/100
# 329/329 [==============================] - ETA: 0s - loss: 0.6872 - mae: 0.5807 - mse: 0.6872
# Epoch 00014: val_loss improved from 0.84776 to 0.84650, saving model to ./models/H18/best_vgg19_tuning.hdf5
# 329/329 [==============================] - 6s 18ms/step - loss: 0.6872 - mae: 0.5807 - mse: 0.6872 - val_loss: 0.8465 - val_mae: 0.6689 - val_mse: 0.8465 - lr: 0.0010
# Epoch 15/100
# 329/329 [==============================] - ETA: 0s - loss: 0.6759 - mae: 0.5747 - mse: 0.6759
# Epoch 00015: val_loss did not improve from 0.84650
# 329/329 [==============================] - 6s 18ms/step - loss: 0.6759 - mae: 0.5747 - mse: 0.6759 - val_loss: 0.8558 - val_mae: 0.6704 - val_mse: 0.8558 - lr: 0.0010
# Epoch 16/100
# 329/329 [==============================] - ETA: 0s - loss: 0.6727 - mae: 0.5748 - mse: 0.6727
# Epoch 00016: val_loss did not improve from 0.84650
# 329/329 [==============================] - 6s 18ms/step - loss: 0.6727 - mae: 0.5748 - mse: 0.6727 - val_loss: 0.8545 - val_mae: 0.6800 - val_mse: 0.8545 - lr: 0.0010
# Epoch 17/100
# 329/329 [==============================] - ETA: 0s - loss: 0.6674 - mae: 0.5735 - mse: 0.6674
# Epoch 00017: val_loss did not improve from 0.84650
# 329/329 [==============================] - 6s 18ms/step - loss: 0.6674 - mae: 0.5735 - mse: 0.6674 - val_loss: 0.8671 - val_mae: 0.6734 - val_mse: 0.8671 - lr: 0.0010
# Epoch 18/100
# 329/329 [==============================] - ETA: 0s - loss: 0.6629 - mae: 0.5704 - mse: 0.6629
# Epoch 00018: val_loss did not improve from 0.84650
# 329/329 [==============================] - 6s 17ms/step - loss: 0.6629 - mae: 0.5704 - mse: 0.6629 - val_loss: 0.8571 - val_mae: 0.6671 - val_mse: 0.8571 - lr: 0.0010
# Epoch 19/100
# 329/329 [==============================] - ETA: 0s - loss: 0.6550 - mae: 0.5690 - mse: 0.6550
# Epoch 00019: val_loss did not improve from 0.84650
# 329/329 [==============================] - 6s 17ms/step - loss: 0.6550 - mae: 0.5690 - mse: 0.6550 - val_loss: 0.8493 - val_mae: 0.6794 - val_mse: 0.8493 - lr: 0.0010
# Epoch 20/100
# 329/329 [==============================] - ETA: 0s - loss: 0.6543 - mae: 0.5665 - mse: 0.6543
# Epoch 00020: val_loss did not improve from 0.84650
# 329/329 [==============================] - 6s 17ms/step - loss: 0.6543 - mae: 0.5665 - mse: 0.6543 - val_loss: 0.8503 - val_mae: 0.6765 - val_mse: 0.8503 - lr: 0.0010
# Epoch 21/100
# 329/329 [==============================] - ETA: 0s - loss: 0.6458 - mae: 0.5624 - mse: 0.6458
# Epoch 00021: val_loss improved from 0.84650 to 0.84636, saving model to ./models/H18/best_vgg19_tuning.hdf5
# 329/329 [==============================] - 7s 21ms/step - loss: 0.6458 - mae: 0.5624 - mse: 0.6458 - val_loss: 0.8464 - val_mae: 0.6815 - val_mse: 0.8464 - lr: 0.0010
# Epoch 22/100
# 329/329 [==============================] - ETA: 0s - loss: 0.6451 - mae: 0.5631 - mse: 0.6451
# Epoch 00022: val_loss improved from 0.84636 to 0.83900, saving model to ./models/H18/best_vgg19_tuning.hdf5
# 329/329 [==============================] - 6s 18ms/step - loss: 0.6451 - mae: 0.5631 - mse: 0.6451 - val_loss: 0.8390 - val_mae: 0.6835 - val_mse: 0.8390 - lr: 0.0010
# Epoch 23/100
# 329/329 [==============================] - ETA: 0s - loss: 0.6371 - mae: 0.5600 - mse: 0.6371
# Epoch 00023: val_loss did not improve from 0.83900
# 329/329 [==============================] - 6s 18ms/step - loss: 0.6371 - mae: 0.5600 - mse: 0.6371 - val_loss: 0.8591 - val_mae: 0.6788 - val_mse: 0.8591 - lr: 0.0010
# Epoch 24/100
# 329/329 [==============================] - ETA: 0s - loss: 0.6333 - mae: 0.5587 - mse: 0.6333
# Epoch 00024: val_loss did not improve from 0.83900
# 329/329 [==============================] - 6s 18ms/step - loss: 0.6333 - mae: 0.5587 - mse: 0.6333 - val_loss: 0.8576 - val_mae: 0.6893 - val_mse: 0.8576 - lr: 0.0010
# Epoch 25/100
# 329/329 [==============================] - ETA: 0s - loss: 0.6249 - mae: 0.5565 - mse: 0.6249
# Epoch 00025: val_loss did not improve from 0.83900
# 329/329 [==============================] - 6s 18ms/step - loss: 0.6249 - mae: 0.5565 - mse: 0.6249 - val_loss: 0.8392 - val_mae: 0.6733 - val_mse: 0.8392 - lr: 0.0010
# Epoch 26/100
# 329/329 [==============================] - ETA: 0s - loss: 0.6275 - mae: 0.5563 - mse: 0.6275
# Epoch 00026: val_loss did not improve from 0.83900
# 329/329 [==============================] - 6s 18ms/step - loss: 0.6275 - mae: 0.5563 - mse: 0.6275 - val_loss: 0.8396 - val_mae: 0.6586 - val_mse: 0.8396 - lr: 0.0010
# Epoch 27/100
# 329/329 [==============================] - ETA: 0s - loss: 0.6209 - mae: 0.5539 - mse: 0.6209
# Epoch 00027: val_loss did not improve from 0.83900
# 329/329 [==============================] - 6s 17ms/step - loss: 0.6209 - mae: 0.5539 - mse: 0.6209 - val_loss: 0.8414 - val_mae: 0.6860 - val_mse: 0.8414 - lr: 0.0010
# Epoch 28/100
# 329/329 [==============================] - ETA: 0s - loss: 0.6240 - mae: 0.5558 - mse: 0.6240
# Epoch 00028: val_loss did not improve from 0.83900
# 329/329 [==============================] - 6s 18ms/step - loss: 0.6240 - mae: 0.5558 - mse: 0.6240 - val_loss: 0.8638 - val_mae: 0.6805 - val_mse: 0.8638 - lr: 0.0010
# Epoch 29/100
# 329/329 [==============================] - ETA: 0s - loss: 0.6174 - mae: 0.5523 - mse: 0.6174
# Epoch 00029: val_loss did not improve from 0.83900
# 329/329 [==============================] - 6s 18ms/step - loss: 0.6174 - mae: 0.5523 - mse: 0.6174 - val_loss: 0.8410 - val_mae: 0.6792 - val_mse: 0.8410 - lr: 0.0010
# Epoch 30/100
# 329/329 [==============================] - ETA: 0s - loss: 0.6167 - mae: 0.5513 - mse: 0.6167
# Epoch 00030: val_loss did not improve from 0.83900
# 329/329 [==============================] - 6s 18ms/step - loss: 0.6167 - mae: 0.5513 - mse: 0.6167 - val_loss: 0.8659 - val_mae: 0.6894 - val_mse: 0.8659 - lr: 0.0010
# Epoch 31/100
# 329/329 [==============================] - ETA: 0s - loss: 0.6135 - mae: 0.5509 - mse: 0.6135
# Epoch 00031: val_loss improved from 0.83900 to 0.82855, saving model to ./models/H18/best_vgg19_tuning.hdf5
# 329/329 [==============================] - 7s 23ms/step - loss: 0.6135 - mae: 0.5509 - mse: 0.6135 - val_loss: 0.8286 - val_mae: 0.6808 - val_mse: 0.8286 - lr: 0.0010
# Epoch 32/100
# 329/329 [==============================] - ETA: 0s - loss: 0.6069 - mae: 0.5494 - mse: 0.6069
# Epoch 00032: val_loss did not improve from 0.82855
# 329/329 [==============================] - 6s 18ms/step - loss: 0.6069 - mae: 0.5494 - mse: 0.6069 - val_loss: 0.8588 - val_mae: 0.6691 - val_mse: 0.8588 - lr: 0.0010
# Epoch 33/100
# 329/329 [==============================] - ETA: 0s - loss: 0.6060 - mae: 0.5464 - mse: 0.6060
# Epoch 00033: val_loss did not improve from 0.82855
# 329/329 [==============================] - 6s 18ms/step - loss: 0.6060 - mae: 0.5464 - mse: 0.6060 - val_loss: 0.8628 - val_mae: 0.6882 - val_mse: 0.8628 - lr: 0.0010
# Epoch 34/100
# 329/329 [==============================] - ETA: 0s - loss: 0.6002 - mae: 0.5462 - mse: 0.6002
# Epoch 00034: val_loss did not improve from 0.82855
# 329/329 [==============================] - 6s 18ms/step - loss: 0.6002 - mae: 0.5462 - mse: 0.6002 - val_loss: 0.8789 - val_mae: 0.6720 - val_mse: 0.8789 - lr: 0.0010
# Epoch 35/100
# 329/329 [==============================] - ETA: 0s - loss: 0.6076 - mae: 0.5485 - mse: 0.6076
# Epoch 00035: val_loss did not improve from 0.82855
# 329/329 [==============================] - 6s 18ms/step - loss: 0.6076 - mae: 0.5485 - mse: 0.6076 - val_loss: 0.8413 - val_mae: 0.6793 - val_mse: 0.8413 - lr: 0.0010
# Epoch 36/100
# 329/329 [==============================] - ETA: 0s - loss: 0.5913 - mae: 0.5406 - mse: 0.5913
# Epoch 00036: val_loss did not improve from 0.82855
# 329/329 [==============================] - 6s 18ms/step - loss: 0.5913 - mae: 0.5406 - mse: 0.5913 - val_loss: 0.9030 - val_mae: 0.7196 - val_mse: 0.9030 - lr: 0.0010
# Epoch 37/100
# 329/329 [==============================] - ETA: 0s - loss: 0.6019 - mae: 0.5445 - mse: 0.6019
# Epoch 00037: val_loss did not improve from 0.82855
# 329/329 [==============================] - 6s 18ms/step - loss: 0.6019 - mae: 0.5445 - mse: 0.6019 - val_loss: 0.8737 - val_mae: 0.6934 - val_mse: 0.8737 - lr: 0.0010
# Epoch 38/100
# 329/329 [==============================] - ETA: 0s - loss: 0.5828 - mae: 0.5389 - mse: 0.5828
# Epoch 00038: val_loss did not improve from 0.82855
# 329/329 [==============================] - 6s 18ms/step - loss: 0.5828 - mae: 0.5389 - mse: 0.5828 - val_loss: 0.8804 - val_mae: 0.7127 - val_mse: 0.8804 - lr: 0.0010
# Epoch 39/100
# 329/329 [==============================] - ETA: 0s - loss: 0.5900 - mae: 0.5412 - mse: 0.5900
# Epoch 00039: val_loss did not improve from 0.82855
# 329/329 [==============================] - 6s 18ms/step - loss: 0.5900 - mae: 0.5412 - mse: 0.5900 - val_loss: 0.8450 - val_mae: 0.6797 - val_mse: 0.8450 - lr: 0.0010
# Epoch 40/100
# 329/329 [==============================] - ETA: 0s - loss: 0.5846 - mae: 0.5390 - mse: 0.5846
# Epoch 00040: val_loss did not improve from 0.82855
# 329/329 [==============================] - 6s 18ms/step - loss: 0.5846 - mae: 0.5390 - mse: 0.5846 - val_loss: 0.8514 - val_mae: 0.6820 - val_mse: 0.8514 - lr: 0.0010
# Epoch 41/100
# 329/329 [==============================] - ETA: 0s - loss: 0.5977 - mae: 0.5440 - mse: 0.5977
# Epoch 00041: ReduceLROnPlateau reducing learning rate to 0.00020000000949949026.
#
# Epoch 00041: val_loss did not improve from 0.82855
# 329/329 [==============================] - 6s 18ms/step - loss: 0.5977 - mae: 0.5440 - mse: 0.5977 - val_loss: 0.8505 - val_mae: 0.6734 - val_mse: 0.8505 - lr: 0.0010
# Epoch 42/100
# 329/329 [==============================] - ETA: 0s - loss: 0.5339 - mae: 0.5142 - mse: 0.5339
# Epoch 00042: val_loss did not improve from 0.82855
# 329/329 [==============================] - 6s 18ms/step - loss: 0.5339 - mae: 0.5142 - mse: 0.5339 - val_loss: 0.8537 - val_mae: 0.6762 - val_mse: 0.8537 - lr: 2.0000e-04
# Epoch 43/100
# 329/329 [==============================] - ETA: 0s - loss: 0.5171 - mae: 0.5060 - mse: 0.5171
# Epoch 00043: val_loss did not improve from 0.82855
# 329/329 [==============================] - 6s 18ms/step - loss: 0.5171 - mae: 0.5060 - mse: 0.5171 - val_loss: 0.8505 - val_mae: 0.6784 - val_mse: 0.8505 - lr: 2.0000e-04
# Epoch 44/100
# 329/329 [==============================] - ETA: 0s - loss: 0.5077 - mae: 0.5035 - mse: 0.5077
# Epoch 00044: val_loss did not improve from 0.82855
# 329/329 [==============================] - 6s 18ms/step - loss: 0.5077 - mae: 0.5035 - mse: 0.5077 - val_loss: 0.8610 - val_mae: 0.6776 - val_mse: 0.8610 - lr: 2.0000e-04
# Epoch 45/100
# 329/329 [==============================] - ETA: 0s - loss: 0.5022 - mae: 0.5005 - mse: 0.5022
# Epoch 00045: val_loss did not improve from 0.82855
# 329/329 [==============================] - 6s 18ms/step - loss: 0.5022 - mae: 0.5005 - mse: 0.5022 - val_loss: 0.8634 - val_mae: 0.6809 - val_mse: 0.8634 - lr: 2.0000e-04
# Epoch 46/100
# 329/329 [==============================] - ETA: 0s - loss: 0.4980 - mae: 0.4992 - mse: 0.4980
# Epoch 00046: val_loss did not improve from 0.82855
# 329/329 [==============================] - 6s 17ms/step - loss: 0.4980 - mae: 0.4992 - mse: 0.4980 - val_loss: 0.8774 - val_mae: 0.6752 - val_mse: 0.8774 - lr: 2.0000e-04
# Epoch 00046: early stopping
# 328/328 [==============================] - 3s 8ms/step
# MAE 0.6752, MSE 0.8774, RMSE 0.9367, MAPE 280.6055
